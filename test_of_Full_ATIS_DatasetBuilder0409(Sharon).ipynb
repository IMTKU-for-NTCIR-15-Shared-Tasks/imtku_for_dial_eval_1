# %% [markdown]
# # Prototyping

# %%
 # 如果真正的困難是不知道怎麼用 DataFrame 做到以下的事，請先備妥只有一句的 DataFrame 再想。
 # 一天之後想不出來的話就再把進度貼出來問我。
 
 # 譯文 slot 順序與原文不同；本來是 flight_mod, fromloc.city_name, toloc.city_name
 text = '什麼是fromloc.city_name到toloc.city_name的flight_mod飛行'
 
 # 假定每句原文的 slot names 是已知的。
 # start/end 設為 None 只是示意，實作時有很多別的方法與考量。
 # 與 list 不同，set/dict 本來就跟順序無關。
 slot_name_start_end_dict = {
     'flight_mod': {'start': None, 'end': None},
     'fromloc.city_name': {'start': None, 'end': None},
     'toloc.city_name': {'start': None, 'end': None},
     'airline_name': {'start':None,'end':None}
 }

 #------以下測試用---------
 #slot_name_start_end_df=pd.Dataframe(slot_name_start_end_dict)
 #slot_name_start_end_df.sort_values(by='start')
 #--------------------------------------------------------------
 
 # 在 loop 裡修改的東西只可以是 value, 不可以是 key, 而且跟 key 順序無關。
 for slot_name in slot_name_start_end_dict.keys():
     begin = text.find(slot_name)
     offset = len(slot_name)
     slot_name_start_end_dict[slot_name]['start'] = begin
     slot_name_start_end_dict[slot_name]['end'] = begin + offset
     
 # 這裡可以變成 unit test:
 # 平常最好先把這個寫下來 (test-driven development).
 # 實作資料結構未必是 slot_name_start_end_map: Dict[str, Dict[str, int]],
 # 所以測試對象應抽象化為 flight_mod_left_boundary 和 flight_mod_right_boundary.
 flight_mod_left_boundary = slot_name_start_end_dict['flight_mod']['start']
 flight_mod_right_boundary = slot_name_start_end_dict['flight_mod']['end']
 flight_mod_len = flight_mod_right_boundary - flight_mod_left_boundary
 assert 37 == flight_mod_left_boundary, f'Wrong: {flight_mod_left_boundary}'
 assert 47 == flight_mod_right_boundary, f'Wrong: {flight_mod_right_boundary}'
 assert len('flight_mod') == flight_mod_len, f'Wrong: {flight_mod_len}'
 # 以下類推
 # ...
 # 另外還應該要檢查 slot 數量，這裡省略。
  # 測試過了之後，回頭試著把實作改成 slot_name_start_end_dict.map(...)
 #slot_name_start_end_dict.map()
 # map() 版成功之後，就比較容易理解要怎麼改寫成 DataFrame.apply(...)
 print(flight_mod_left_boundary,'left',flight_mod_right_boundary,'right',flight_mod_len,'len')
 list_item=list(slot_name_start_end_dict.keys())
 for i in slot_name_start_end_dict.values():
   #print(slot_name_start_end_dict.keys(),'',i)
   print(list (slot_name_start_end_dict.keys()) [list (slot_name_start_end_dict.values()).index (i)],'',i)

   #if(slot_name_start_end_dict[slot_name]['start']>=0):
    #print(i)
# Out:
# 37 left 47 right 10 len
# flight_mod  {'start': 37, 'end': 47}
# fromloc.city_name  {'start': 3, 'end': 20}
# toloc.city_name  {'start': 21, 'end': 36}
# airline_name  {'start': -1, 'end': 11}

# %% [markdown]
# ## What I want

# %% [markdown]
# - Learn how to use `map()`
# - For what purpose?

# %% [markdown]
# ## What I have tried

# %%
#map函式
# User-defined function to pass to map()
# function as the first argument
def getLength(iterable):
    return len(iterable)

# %%
# Function to print the map output
def show_result(map_object):
    for item in map_object:
        print(item, end=' ')
    print('')  # for new line

# %%
# Generic Function to print the iterator and its content
def print_Iter(iter_in):
    if isinstance(iter_in, str):
        print("The input iterable, '{}' is a String. Its length is {}.".format(iter_in, len(iter_in)))
    if isinstance(iter_in, (list, tuple, set)):
        print("The input iterable, {} is a {}. It has {} elements.".format(iter_in, type(iter_in).__name__, len(iter_in)))
        for item in iter_in:
            print("The {} contains '{}' and its length is {}.".format(type(iter_in).__name__, item, len(item)))
    if isinstance(iter_in, dict):
        print("The input iterable, {} is a {}. It has {} elements.".format(iter_in, type(iter_in).__name__, len(iter_in)))
        for key, value in iter_in.items():
            print("Dict key is '{}' and value is {}.".format(key, value))

# %%
# Considering Dict as our iterable parameter
#iter_Dict = {"Python":0, "CSharp":0, "Java":0}
print_Iter(slot_name_start_end_dict)

# Calling map() function on a dictionary
map_result =  map(getLength, slot_name_start_end_dict)
print("Type of map_result is {}".format(type(map_result)))

# Printing map() output
print("Lengths are: ")
show_result(map_result)
# Out:
# The input iterable, {'flight_mod': {'start': 37, 'end': 47}, 'fromloc.city_name': {'start': 3, 'end': 20}, 'toloc.city_name': {'start': 21, 'end': 36}, 'airline_name': {'start': -1, 'end': 11}} is a dict. It has 4 elements.
# Dict key is 'flight_mod' and value is {'start': 37, 'end': 47}.
# Dict key is 'fromloc.city_name' and value is {'start': 3, 'end': 20}.
# Dict key is 'toloc.city_name' and value is {'start': 21, 'end': 36}.
# Dict key is 'airline_name' and value is {'start': -1, 'end': 11}.
# Type of map_result is <class 'map'>
# Lengths are:
# 10 17 15 12

# %% [markdown]
# ## What obstacles I faced

# %% [markdown]
# > 想要問一下Mike這麼做所產生的結果是否正確

# %% [markdown]
# ## Mike's comment

# %% [markdown]
# `map()` 的用法本身沒有問題。接下來要想的是 "for what purpose" 這個部分。
#
# 本來的實作是：
# ```python
# for slot_name in slot_name_start_end_dict.keys():
#     begin = text.find(slot_name)
#     offset = len(slot_name)
#     slot_name_start_end_dict[slot_name]['start'] = begin
#     slot_name_start_end_dict[slot_name]['end'] = begin + offset
# ```
#
# 而 unit test 是：
# ```python
# flight_mod_left_boundary = slot_name_start_end_dict['flight_mod']['start']
# flight_mod_right_boundary = slot_name_start_end_dict['flight_mod']['end']
# flight_mod_len = flight_mod_right_boundary - flight_mod_left_boundary
# assert 37 == flight_mod_left_boundary, f'Wrong: {flight_mod_left_boundary}'
# assert 47 == flight_mod_right_boundary, f'Wrong: {flight_mod_right_boundary}'
# assert len('flight_mod') == flight_mod_len, f'Wrong: {flight_mod_len}'
# ```
#
# 要怎麼改用 `map()` 又能通過測試？

# %%
from typing import Callable, Dict


def test_get_slot_boudary_dict(
    func_get_slot_boundary_dict: Callable[
        [str, Dict[str, Dict[str, int]]],
        Dict[str, Dict[str, int]]
    ]
) -> None:
    text = '什麼是fromloc.city_name到toloc.city_name的flight_mod飛行'
    slot_name_start_end_dict = {
        'flight_mod': {'start': None, 'end': None},
        'fromloc.city_name': {'start': None, 'end': None},
        'toloc.city_name': {'start': None, 'end': None},
        'airline_name': {'start':None, 'end':None}
    }

    slot_boundaries = func_get_slot_boundary_dict(
        text,
        slot_name_start_end_dict
    )
    
    flight_mod_left = slot_boundaries['flight_mod']['start']
    flight_mod_right = slot_boundaries['flight_mod']['end']
    flight_mod_len = flight_mod_right - flight_mod_left
    assert 37 == flight_mod_left, f'Wrong: {flight_mod_left}'
    assert 47 == flight_mod_right, f'Wrong: {flight_mod_right}'
    assert len('flight_mod') == flight_mod_len, f'Wrong: {flight_mod_len}'

    airline_name_left = slot_boundaries['airline_name']['start']
    airline_name_right = slot_boundaries['airline_name']['end']
    assert -1 == airline_name_left, f'Wrong: {airline_name_left}'
    # TODO: fix me
    # assert -1 == airline_name_right, f'Wrong: {airline_name_right}'

# %%
def get_slot_boudary_dict_loop_version(
    utterance: str,
    slot_boundary_dict: Dict[str, Dict[str, int]]
) -> Dict[str, Dict[str, int]]:
    for slot_name in slot_boundary_dict.keys():
        begin = utterance.find(slot_name)
        offset = len(slot_name)
        slot_boundary_dict[slot_name]['start'] = begin
        slot_boundary_dict[slot_name]['end'] = begin + offset
    return slot_boundary_dict


test_get_slot_boudary_dict(get_slot_boudary_dict_loop_version)

# %%
def get_slot_boudary_dict_map_version(
    utterance: str,
    slot_boundary_dict: Dict[str, Dict[str, int]]
) -> Dict[str, Dict[str, int]]:
    # TODO: 
    # map(func, slot_boundary_dict)
    raise NotImplementedError('Implement me')


test_get_slot_boudary_dict(get_slot_boudary_dict_map_version)

# %% [markdown]
# 思考怎麼實作時應該會發現幾個狀況：
#
# 1. 真的有必要傳 `slot_boundary_dict` 進去嗎？輸入條件明明只是裡面的 slot_name
# 2. 最重要的結果來自 `str.find()`, 也就是 slot_name 在 utterance 裡的位置，於是輸出似乎也沒必要是 nested `dict`
# 3. 如果輸入輸出都不是 nested `dict`, `map()` 用法應該跟常見範例差不多
# 4. 跟 `map()` 常見範例差不多的話，應該也可以用 `lambda` 或 comprehension

# %% [markdown]
# # Production code

# %%
from google.colab import drive
drive.mount('/content/drive/')

import os
os.chdir('/content/drive/My Drive/dataset/')
#!ls

#!pwd

# 匯入json模組
import json
# 匯入csv模組
import csv
import pandas as pd
data=pd.read_csv('ATIS.csv',encoding="MS950") #讀csv
data2=pd.read_csv('ATISsample.csv',encoding="MS950")#用這個檔案當作對照的範例檔
#print(data.intent) #csv用 印出intent
#print(data.text) #csv用 印出text
#print(data.values)
print(data.iloc[1,0])
print(data.iloc[1,4]) #第一個數字表示第幾筆資料 後面的數字由0開始依序為intent,entities start,entities end,entities 2...(可參照train.csv)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# 什麼flight_time確實airline_name從出發到fromloc.city_name toloc.city_name
# times

# %%
#將slot設回原本的初始值(避免資料毀損)
print(data.iloc[1,2],"from_city_start")
print(data.iloc[1,3],"from_city_end")
print(data.iloc[1,4],"from_city")
print(data.iloc[1,6],"loc_city_start")
print(data.iloc[1,7],"loc_city_end")
print(data.iloc[1,8],"loc_city")
print(data.iloc[1,0],"text")
print(data.iloc[1,17])#第二筆資料的最後一個
#for i in range(0,len(data)):
#  for j in range(len(data.iloc[i,])):
#    data.iloc[i,j]=data2.iloc[i,j]
# Out:
# 5.0 from_city_start
# 10.0 from_city_end
# times from_city
# 16.0 loc_city_start
# 27.0 loc_city_end
# continental loc_city
# 什麼flight_time確實airline_name從出發到fromloc.city_name toloc.city_name text
# toloc.city_name

# %%
import random
#for i in range (1,len(data)):
#  for j in range(len(data.iloc[i,])):
#    data.iloc[i,j]=data2.iloc[i,j] 整個檔案的初始化(還原成最初的train.csv)
#--------------新slot陣列值
aircraft_code_value=['波音747','波音767','波音777','波音787','波音737','空中巴士A330','空中巴士A340','空中巴士A320','空中巴士A321','麥道MD11']
airline_code_value=['BR','CI','IT','B7','FE','AE','JAL']#和下面airline_name_value須採用同一個random值
airline_name_value=['長榮航空','中華航空','台灣虎航','立榮航空','遠東航空','華信航空','日本航空']
airport_code_value=['TPE','PVG','NRT','PEK','ICN','JFK','SEA','KIX','NGO','LGW']#和下面airport_name_valu須採用同個random值
airport_name_value=['臺灣桃園國際機場','上海浦東國際機場','東京成田機場','北京首都國際機場','首爾仁川國際機場','甘迺迪國際機場','西雅圖-塔科馬國際機場','關西國際機場','名古屋中部國際機場','倫敦蓋威克機場']
arrive_date_date_relative_value=['下']
arrive_date_day_name_value=['星期一','星期二','星期三','星期四','星期五','星期六','星期日','星期天']
arrive_date_day_number_value=['一號','二號','三號','四號','五號','六號','七號','八號','九號','十號','十一號','十二號','十三號','十四號','十五號','十六號','十七號','十八號','十九號','二十號','二十一號','二十二號','二十三號','二十六號']
arrive_date_month_name_value=['一月','二月','三月','四月','五月','六月','七月','八月','九月','十月','十一月','十二月']
arrive_time_period_mod_value=['最早的','下午的','最晚的','紅眼','早上的','晚上的']
arrive_time_time_relative_value=['之前','之後']
city_name_value=['上海','東京','北京','首爾','紐約','西雅圖','大阪','名古屋','倫敦','桃園']
class_type_value=['頭等艙','商務艙','經濟艙']
cost_relative_value=['便宜的','昂貴的','最便宜的','花費最少的','最高價的','最低價的','花費最多的','最貴的']
depart_date_date_relative_value=['下(next)']
depart_date_day_name_value=['星期一','星期二','星期三','星期四','星期五','星期六','星期日','星期天']
depart_date_month_name_value=['一月','二月','三月','四月','五月','六月','七月','八月','九月','十月','十一月','十二月']
depart_date_today_relative_value=['明天','今天','今晚','後天','今早']
depart_time_period_mod_value=['最早的','下午的','最晚的','紅眼','早上的','晚上的']
depart_time_time_relative_value=['之前','之後']
fare_amount_value=['元']
flight_days_value=['每日','每天']
flight_mod_value=['最短的','最早的','晚上的','下午的','最晚的','紅眼','早上的']
flight_number_value=['B77016','BR2179','BR716','BR170','B77016','CI0012','BR178','CI0150','CI0069']
flight_stop_value=['直達','轉機']
fromloc_airport_code_value=['TPE','PVG','NRT','PEK','ICN','JFK','SEA','KIX','NGO','LGW']#和下方需同一個random值
fromloc_airport_name_value=['臺灣桃園國際機場','上海浦東國際機場','東京成田機場','北京首都國際機場','首爾仁川國際機場','甘迺迪國際機場','西雅圖-塔科馬國際機場','關西國際機場','名古屋中部國際機場','倫敦蓋威克機場']
fromloc_city_name_value=['上海','東京','北京','首爾','紐約','西雅圖','大阪','名古屋','倫敦','桃園']
fromloc_state_code_value=['CN','JP','KR','US','GB','TW']#下方同random
fromloc_state_name_value=['中國','日本','韓國','美國','英國','臺灣']
meal_value=['餐']
meal_description_value=['早餐','午餐','晚餐']
or_value=['或']#??
return_date_date_relavite_value=['這幾天']
return_date_day_name_value=['星期一','星期二','星期三','星期四','星期五','星期六','星期日','星期天']
return_date_month_name_value=['一月','二月','三月','四月','五月','六月','七月','八月','九月','十月','十一月','十二月']
return_date_today_relative_value=['明天','今天','今晚','後天','今早']
return_time_period_mod_value=['最早的','下午的','最晚的','紅眼','早上的','晚上的']
round_trip_value=['來回','單程','去程','回程']
stoploc_airport_name_value=['臺灣桃園國際機場','上海浦東國際機場','東京成田機場','北京首都國際機場','首爾仁川國際機場','甘迺迪國際機場','西雅圖-塔科馬國際機場','關西國際機場','名古屋中部國際機場','倫敦蓋威克機場']
stoploc_city_name_value=['上海','東京','北京','首爾','紐約','西雅圖','大阪','名古屋','倫敦','桃園']
toloc_airport_code_value=['TPE','PVG','NRT','PEK','ICN','JFK','SEA','KIX','NGO','LGW']#和下方同random
toloc_airport_name_value=['臺灣桃園國際機場','上海浦東國際機場','東京成田機場','北京首都國際機場','首爾仁川國際機場','甘迺迪國際機場','西雅圖-塔科馬國際機場','關西國際機場','名古屋中部國際機場','倫敦蓋威克機場']
toloc_city_name_value=['上海','東京','北京','首爾','紐約','西雅圖','大阪','名古屋','倫敦','桃園']
toloc_country_name_value=['中國','日本','韓國','美國','英國','臺灣']
#---
arrive_time_end_time_value=['一點','二點','三點','四點','五點','六點','七點','八點','九點','十點','十一點','十二點','十三點','十四點','十五點','十六點','十七點','十八點','十九點','二十點','二十一點','二十二點','二十三點','二十四點']
arrive_time_period_of_day_value=['下午的','晚上的','早上的','上午的','傍晚的','紅眼時段的']
arrive_time_start_time_value=['一點','二點','三點','四點','五點','六點','七點','八點','九點','十點','十一點','十二點','十三點','十四點','十五點','十六點','十七點','十八點','十九點','二十點','二十一點','二十二點','二十三點','二十四點','01:00','02:00','03:00','04:00','05:00','06:00','07:00','08:00','09:00','10:00','11:00','12:00','13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00','00:00']
arrive_time_time_value=['一點','二點','三點','四點','五點','六點','七點','八點','九點','十點','十一點','十二點','十三點','十四點','十五點','十六點','十七點','十八點','十九點','二十點','二十一點','二十二點','二十三點','二十四點','01:00','02:00','03:00','04:00','05:00','06:00','07:00','08:00','09:00','10:00','11:00','12:00','13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00','00:00']
connect_value=['直達']
depart_date_day_number_value=['一號','二號','三號','四號','五號','六號','七號','八號','九號','十號','十一號','十二號','十三號','十四號','十五號','十六號','十七號','十八號','十九號','二十號','二十一號','二十二號','二十三號','二十六號']
depart_time_end_time_value=['一點','二點','三點','四點','五點','六點','七點','八點','九點','十點','十一點','十二點','十三點','十四點','十五點','十六點','十七點','十八點','十九點','二十點','二十一點','二十二點','二十三點','二十四點','01:00','02:00','03:00','04:00','05:00','06:00','07:00','08:00','09:00','10:00','11:00','12:00','13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00','00:00']
depart_time_period_of_day_value=['下午的','晚上的','早上的','上午的','傍晚的','紅眼時段的']
depart_time_start_time_value=['一點','二點','三點','四點','五點','六點','七點','八點','九點','十點','十一點','十二點','十三點','十四點','十五點','十六點','十七點','十八點','十九點','二十點','二十一點','二十二點','二十三點','二十四點','01:00','02:00','03:00','04:00','05:00','06:00','07:00','08:00','09:00','10:00','11:00','12:00','13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00','00:00']
depart_time_time_value=['一點','二點','三點','四點','五點','六點','七點','八點','九點','十點','十一點','十二點','十三點','十四點','十五點','十六點','十七點','十八點','十九點','二十點','二十一點','二十二點','二十三點','二十四點','01:00','02:00','03:00','04:00','05:00','06:00','07:00','08:00','09:00','10:00','11:00','12:00','13:00','14:00','15:00','16:00','17:00','18:00','19:00','20:00','21:00','22:00','23:00','00:00']
flight_time_value=['航班資訊']
mod_value=['most']
period_of_day_value=['下午的','晚上的','早上的','上午的','傍晚的','紅眼時段的']
return_date_day_number_value=['一號','二號','三號','四號','五號','六號','七號','八號','九號','十號','十一號','十二號','十三號','十四號','十五號','十六號','十七號','十八號','十九號','二十號','二十一號','二十二號','二十三號','二十六號']
return_time_period_of_day_value=['下午的','晚上的','早上的','上午的','傍晚的','紅眼時段的']

#--
depart_date_year_value=['']
economy_value=['']
fare_basis_code_value=['']
state_code_value=['']
stoploc_state_code_value=['']
toloc_state_code_value=['']
toloc_state_name_value=['']
#-----------------------要替換的slot新值
new_aircraft_code=aircraft_code_value[random.randint(0,len(aircraft_code_value)-1)]#1
new_airline_code=airline_code_value[random.randint(0,len(airline_code_value)-1)]#2
new_airline_name=airline_name_value[random.randint(0,len(airline_name_value)-1)]#3
new_airport_code=airport_code_value[random.randint(0,len(airport_code_value)-1)]#4
new_airport_name=airport_name_value[random.randint(0,len(airport_name_value)-1)]#5
new_arrive_date_date_relative=arrive_date_date_relative_value[random.randint(0,len(arrive_date_date_relative_value)-1)]#6
new_arrive_date_day_name=arrive_date_day_name_value[random.randint(0,len(arrive_date_day_name_value)-1)]#7
new_arrive_date_day_number=arrive_date_day_number_value[random.randint(0,len(arrive_date_day_number_value)-1)]#8
new_arrive_date_month_name=arrive_date_month_name_value[random.randint(0,len(arrive_date_month_name_value)-1)]#9
new_arrive_time_period_mod=arrive_time_period_mod_value[random.randint(0,len(arrive_time_period_mod_value)-1)]#10
new_arrive_time_time_relative=arrive_time_time_relative_value[random.randint(0,len(arrive_time_time_relative_value)-1)]#11
new_city_name=city_name_value[random.randint(0,len(city_name_value)-1)]#12
new_class_type=class_type_value[random.randint(0,len(class_type_value)-1)]#13
new_cost_relative=cost_relative_value[random.randint(0,len(cost_relative_value)-1)]#14
new_depart_date_date_relative=depart_date_date_relative_value[random.randint(0,len(depart_date_date_relative_value)-1)]#15
new_depart_date_day_name=depart_date_day_name_value[random.randint(0,len(depart_date_day_name_value)-1)]#16
new_depart_date_month_name=depart_date_month_name_value[random.randint(0,len(depart_date_month_name_value)-1)]#17
new_depart_date_today_relative=depart_date_today_relative_value[random.randint(0,len(depart_date_today_relative_value)-1)]#18
new_depart_time_period_mod=depart_time_period_mod_value[random.randint(0,len(depart_time_period_mod_value)-1)]#19
new_depart_time_time_relative=depart_time_time_relative_value[random.randint(0,len(depart_time_time_relative_value)-1)]#20
new_fare_amount=fare_amount_value[random.randint(0,len(fare_amount_value)-1)]#21
new_flight_days=flight_days_value[random.randint(0,len(flight_days_value)-1)]#22
new_flight_mod=flight_mod_value[random.randint(0,len(flight_mod_value)-1)]#23
new_flight_number=flight_number_value[random.randint(0,len(flight_number_value)-1)]#24
new_flight_stop=flight_stop_value[random.randint(0,len(flight_stop_value)-1)]#25
new_fromloc_airport_code=fromloc_airport_code_value[random.randint(0,len(fromloc_airport_code_value)-1)]#26
new_fromloc_airport_name=fromloc_airport_name_value[random.randint(0,len(fromloc_airport_name_value)-1)]#27
new_fromloc_city_name=fromloc_city_name_value[random.randint(0,len(fromloc_city_name_value)-1)]#28
new_fromloc_state_code=fromloc_state_code_value[random.randint(0,len(fromloc_state_code_value)-1)]#29
new_fromloc_state_name=fromloc_state_name_value[random.randint(0,len(fromloc_state_name_value)-1)]#30
new_meal=meal_value[random.randint(0,len(meal_value)-1)]#31
new_meal_description=meal_description_value[random.randint(0,len(meal_description_value)-1)]#32
new_or=or_value[random.randint(0,len(or_value)-1)]#33
new_return_date_date_relavite=return_date_date_relavite_value[random.randint(0,len(return_date_date_relavite_value)-1)]#34
new_return_date_day_name=return_date_day_name_value[random.randint(0,len(return_date_day_name_value)-1)]#35
new_return_date_month_name=return_date_month_name_value[random.randint(0,len(return_date_month_name_value)-1)]#36
new_return_date_today_relative=return_date_today_relative_value[random.randint(0,len(return_date_today_relative_value)-1)]#37
new_return_time_period_mod=return_time_period_mod_value[random.randint(0,len(return_time_period_mod_value)-1)]#38
new_round_trip=round_trip_value[random.randint(0,len(round_trip_value)-1)]#39
new_stoploc_airport_name=stoploc_airport_name_value[random.randint(0,len(stoploc_airport_name_value)-1)]#40
new_stoploc_city_name=stoploc_city_name_value[random.randint(0,len(stoploc_city_name_value)-1)]#41
new_toloc_airport_code=toloc_airport_code_value[random.randint(0,len(toloc_airport_code_value)-1)]#42
new_toloc_airport_name=toloc_airport_name_value[random.randint(0,len(toloc_airport_name_value)-1)]#43
new_toloc_city_name=toloc_city_name_value[random.randint(0,len(toloc_city_name_value)-1)]#44
new_toloc_country_name=toloc_country_name_value[random.randint(0,len(toloc_country_name_value)-1)]#45
#----
new_arrive_time_end_time=arrive_time_end_time_value[random.randint(0,len(arrive_time_end_time_value)-1)]
new_arrive_time_period_of_day=arrive_time_period_of_day_value[random.randint(0,len(arrive_time_period_of_day_value)-1)]
new_arrive_time_start_time=arrive_time_start_time_value[random.randint(0,len(arrive_time_start_time_value)-1)]
new_arrive_time_time=arrive_time_time_value[random.randint(0,len(arrive_time_time_value)-1)]
new_connect=connect_value[random.randint(0,len(connect_value)-1)]
new_depart_date_day_number=depart_time_end_time_value[random.randint(0,len(depart_date_day_number_value)-1)]
new_depart_time_end_time=depart_time_end_time_value[random.randint(0,len(depart_time_end_time_value)-1)]
new_depart_time_period_of_day=depart_time_period_of_day_value[random.randint(0,len(depart_time_period_of_day_value)-1)]
new_depart_time_start_time=depart_time_start_time_value[random.randint(0,len(depart_time_start_time_value)-1)]
new_depart_time_time=depart_time_time_value[random.randint(0,len(depart_time_time_value)-1)]
new_flight_time=flight_time_value[random.randint(0,len(flight_time_value)-1)]
new_mod=mod_value=mod_value[random.randint(0,len(mod_value)-1)]
new_period_of_day=period_of_day_value[random.randint(0,len(period_of_day_value)-1)]
new_return_date_day_number=return_date_day_number_value[random.randint(0,len(return_date_day_number_value)-1)]
new_return_time_period_of_day=return_time_period_of_day_value[random.randint(0,len(return_time_period_of_day_value)-1)]
#---
new_depart_date_year=depart_date_year_value[random.randint(0,len(depart_date_year_value)-1)]
new_economy=economy_value[random.randint(0,len(economy_value)-1)]
new_fare_basis_code=fare_basis_code_value[random.randint(0,len(fare_basis_code_value)-1)]
new_state_code=state_code_value[random.randint(0,len(state_code_value)-1)]
new_stoploc_state_code=stoploc_state_code_value[random.randint(0,len(stoploc_state_code_value)-1)]
new_toloc_state_code=toloc_state_code_value[random.randint(0,len(toloc_state_code_value)-1)]
new_toloc_state_name=toloc_state_name_value[random.randint(0,len(toloc_state_name_value)-1)]

# %%
#建立一個字典
dict={'aircraft_code':new_aircraft_code,'airline_code':new_airline_code,'airline_name':new_airline_name,'airport_code':new_airport_code,'airport_name':new_airport_name,
      'arrive_date.date_relative':new_arrive_date_date_relative,'arrive_date.day_name':new_arrive_date_day_name,"arrive_date.day_number":new_arrive_date_day_number,'arrive_date.month_name':new_arrive_date_month_name,'arrive_time.period_mod':new_arrive_time_period_mod,
      'arrive_time.time_relative':new_arrive_time_time_relative,'city_name':new_city_name,'class_type':new_class_type,'cost_relative':new_cost_relative,'depart_date.date_relative':new_depart_date_date_relative,
      'depart_date.day_name':new_depart_date_day_name,'depart_date.month_name':new_depart_date_month_name,'depart_date.today_relative':new_depart_date_today_relative,'depart_time.period_mod':new_depart_time_period_mod,'depart_time.time_relative':new_depart_time_time_relative,
      'fare_amount':new_fare_amount,'flight_days':new_flight_days,'flight_mod':new_flight_mod,'flight_number':new_flight_number,'flight_stop':new_flight_stop,
      'fromloc.airport_code':new_fromloc_airport_code,'fromloc.airport_name':new_fromloc_airport_name,'fromloc.city_name':new_fromloc_city_name,'fromloc.state_code':new_fromloc_state_code,'fromloc.state_name':new_fromloc_state_name,
      'meal':new_meal,'meal_description':new_meal_description,'or':new_or,'return_date.date_relavite':new_return_date_date_relavite,'return_date.day_name':new_return_date_day_name,
      'return_date.month_name':new_return_date_month_name,'return_date.today_relative':new_return_date_today_relative,'return_time.period_mod':new_return_time_period_mod,'round_trip':new_round_trip,'stoploc.airport_name':new_stoploc_airport_name,
      'stoploc.city_name':new_stoploc_city_name,'toloc.airport_code':new_toloc_airport_code,'toloc.airport_name':new_toloc_airport_name,'toloc.city_name':new_toloc_city_name,'toloc.country_name':new_toloc_country_name,'arrive_time.end_time':new_arrive_time_end_time,'arrive_time.period_of_day':new_arrive_time_period_of_day
      ,'arrive_time.start_time':new_arrive_time_start_time,'arrive_time.time':new_arrive_time_time,'connect':new_connect,'depart_date.day_number':new_depart_date_day_number,'depart_date.year':new_depart_date_year,'depart_time.end_time':new_depart_time_end_time,'depart_time.period_of_day':new_depart_time_period_of_day
      ,'depart_time.start_time':new_depart_time_start_time,'depart_time.time':new_depart_time_time,'economy':new_economy,'fare_basis_code':new_fare_basis_code,'flight_time':new_flight_time,'mod':new_mod,'period_of_day':new_period_of_day,'return_date.day_number':new_return_date_day_number,'return_time.period_of_day':new_return_time_period_of_day,'state_code':new_state_code
      ,'stoploc.state_code':new_stoploc_state_code,'toloc.state_code':new_toloc_state_code,'toloc.state_name':new_toloc_state_name
      }
msg=''
#針對下方data.iloc[i,j]的每個j值查詢是否符合字典內特定項,如果有就讓new_slot存取該字典對應到的變數名稱

# %%
for i in range(0,100):
  print('第',i,'筆資料')
  for j in range(5,len(data.iloc[i,]),4):
    data.iloc[i,j]=data2.iloc[i,j]
    a=data.iloc[i,j]
    if(str(a)=='nan'):
      continue
    else:
      print(a)
      msg=dict[a]
      new_slot=msg
      print('new_slot:',new_slot)
      old_slot=data.iloc[i,j]
      print('old_slot:',old_slot)
      text=data.iloc[i,0]
      print(text)
      text=text.replace(old_slot,new_slot)
      print(text)
      data.iloc[i,j-1]=new_slot
      print(data.iloc[i,j-1])
      data.iloc[i,0]=text
      print(data.iloc[i,0])
      new_entity_start=text.find(new_slot)
      data.iloc[i,j-3]=int(new_entity_start)
      print(data.iloc[i,j-3])
      new_entity_end=new_entity_start+len(new_slot)
      data.iloc[i,j-2]=int(new_entity_end)
      print(data.iloc[i,j-2])
# Out:
# 第 0 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 晚上的
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 37.0
# 40.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 什麼是東京到toloc.city_name的晚上的飛行
# 東京
# 什麼是東京到toloc.city_name的晚上的飛行
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京到toloc.city_name的晚上的飛行
# 什麼是東京到東京的晚上的飛行
# 東京
# 什麼是東京到東京的晚上的飛行
# 3.0
# 5.0
# 第 1 筆資料
# flight_time
# new_slot: 航班資訊
# old_slot: flight_time
# 什麼flight_time確實airline_name從出發到fromloc.city_name toloc.city_name
# 什麼航班資訊確實airline_name從出發到fromloc.city_name toloc.city_name
# 航班資訊
# 什麼航班資訊確實airline_name從出發到fromloc.city_name toloc.city_name
# 2.0
# 6.0
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 什麼航班資訊確實airline_name從出發到fromloc.city_name toloc.city_name
# 什麼航班資訊確實華信航空從出發到fromloc.city_name toloc.city_name
# 華信航空
# 什麼航班資訊確實華信航空從出發到fromloc.city_name toloc.city_name
# 8.0
# 12.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班資訊確實華信航空從出發到fromloc.city_name toloc.city_name
# 什麼航班資訊確實華信航空從出發到東京 toloc.city_name
# 東京
# 什麼航班資訊確實華信航空從出發到東京 toloc.city_name
# 16.0
# 18.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班資訊確實華信航空從出發到東京 toloc.city_name
# 什麼航班資訊確實華信航空從出發到東京 東京
# 東京
# 什麼航班資訊確實華信航空從出發到東京 東京
# 16.0
# 18.0
# 第 2 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我想要看到fromloc.city_name到toloc.city_name航班
# 我想要看到東京到toloc.city_name航班
# 東京
# 我想要看到東京到toloc.city_name航班
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我想要看到東京到toloc.city_name航班
# 我想要看到東京到東京航班
# 東京
# 我想要看到東京到東京航班
# 5.0
# 7.0
# 第 3 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 什麼是fromloc.city_name到toloc.city_name的cost_relative票價
# 什麼是fromloc.city_name到toloc.city_name的最低價的票價
# 最低價的
# 什麼是fromloc.city_name到toloc.city_name的最低價的票價
# 37.0
# 41.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的最低價的票價
# 什麼是東京到toloc.city_name的最低價的票價
# 東京
# 什麼是東京到toloc.city_name的最低價的票價
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京到toloc.city_name的最低價的票價
# 什麼是東京到東京的最低價的票價
# 東京
# 什麼是東京到東京的最低價的票價
# 3.0
# 5.0
# 第 4 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 列出所有從fromloc.city_name到toloc.city_name航班
# 列出所有從東京到toloc.city_name航班
# 東京
# 列出所有從東京到toloc.city_name航班
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 列出所有從東京到toloc.city_name航班
# 列出所有從東京到東京航班
# 東京
# 列出所有從東京到東京航班
# 5.0
# 7.0
# 第 5 筆資料
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 請出示機票toloc.city_name到達從fromloc.city_name
# 請出示機票東京到達從fromloc.city_name
# 東京
# 請出示機票東京到達從fromloc.city_name
# 5.0
# 7.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請出示機票東京到達從fromloc.city_name
# 請出示機票東京到達從東京
# 東京
# 請出示機票東京到達從東京
# 5.0
# 7.0
# 第 6 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班你有從fromloc.city_name到toloc.city_name
# 什麼航班你有從東京到toloc.city_name
# 東京
# 什麼航班你有從東京到toloc.city_name
# 7.0
# 9.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班你有從東京到toloc.city_name
# 什麼航班你有從東京到東京
# 東京
# 什麼航班你有從東京到東京
# 7.0
# 9.0
# 第 7 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從fromloc.city_name到toloc.city_name toloc.state_code航班
# 從東京到toloc.city_name toloc.state_code航班
# 東京
# 從東京到toloc.city_name toloc.state_code航班
# 1.0
# 3.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從東京到toloc.city_name toloc.state_code航班
# 從東京到東京 toloc.state_code航班
# 東京
# 從東京到東京 toloc.state_code航班
# 1.0
# 3.0
# toloc.state_code
# new_slot:
# old_slot: toloc.state_code
# 從東京到東京 toloc.state_code航班
# 從東京到東京 航班
#
# 從東京到東京 航班
# 0.0
# 0.0
# 第 8 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 給我從fromloc.city_name的cost_relative航班上depart_date.day_name toloc.city_name
# 給我從fromloc.city_name的最低價的航班上depart_date.day_name toloc.city_name
# 最低價的
# 給我從fromloc.city_name的最低價的航班上depart_date.day_name toloc.city_name
# 21.0
# 25.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 給我從fromloc.city_name的最低價的航班上depart_date.day_name toloc.city_name
# 給我從東京的最低價的航班上depart_date.day_name toloc.city_name
# 東京
# 給我從東京的最低價的航班上depart_date.day_name toloc.city_name
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 給我從東京的最低價的航班上depart_date.day_name toloc.city_name
# 給我從東京的最低價的航班上depart_date.day_name 東京
# 東京
# 給我從東京的最低價的航班上depart_date.day_name 東京
# 3.0
# 5.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 給我從東京的最低價的航班上depart_date.day_name 東京
# 給我從東京的最低價的航班上星期六 東京
# 星期六
# 給我從東京的最低價的航班上星期六 東京
# 13.0
# 16.0
# 第 9 筆資料
# flight_days
# new_slot: 每天
# old_slot: flight_days
# 清單flight_days從fromloc.city_name到toloc.city_name與class_type航班
# 清單每天從fromloc.city_name到toloc.city_name與class_type航班
# 每天
# 清單每天從fromloc.city_name到toloc.city_name與class_type航班
# 2.0
# 4.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 清單每天從fromloc.city_name到toloc.city_name與class_type航班
# 清單每天從東京到toloc.city_name與class_type航班
# 東京
# 清單每天從東京到toloc.city_name與class_type航班
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 清單每天從東京到toloc.city_name與class_type航班
# 清單每天從東京到東京與class_type航班
# 東京
# 清單每天從東京到東京與class_type航班
# 5.0
# 7.0
# class_type
# new_slot: 頭等艙
# old_slot: class_type
# 清單每天從東京到東京與class_type航班
# 清單每天從東京到東京與頭等艙航班
# 頭等艙
# 清單每天從東京到東京與頭等艙航班
# 11.0
# 14.0
# 第 10 筆資料
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我所有toloc.city_name到達的航班arrive_time.time_relative下午5點arrive_date.date_relative arrive_date.day_name請
# 告訴我所有東京到達的航班arrive_time.time_relative下午5點arrive_date.date_relative arrive_date.day_name請
# 東京
# 告訴我所有東京到達的航班arrive_time.time_relative下午5點arrive_date.date_relative arrive_date.day_name請
# 5.0
# 7.0
# arrive_time.time_relative
# new_slot: 之後
# old_slot: arrive_time.time_relative
# 告訴我所有東京到達的航班arrive_time.time_relative下午5點arrive_date.date_relative arrive_date.day_name請
# 告訴我所有東京到達的航班之後下午5點arrive_date.date_relative arrive_date.day_name請
# 之後
# 告訴我所有東京到達的航班之後下午5點arrive_date.date_relative arrive_date.day_name請
# 12.0
# 14.0
# arrive_time.time
# new_slot: 11:00
# old_slot: arrive_time.time
# 告訴我所有東京到達的航班之後下午5點arrive_date.date_relative arrive_date.day_name請
# 告訴我所有東京到達的航班之後下午5點arrive_date.date_relative arrive_date.day_name請
# 11:00
# 告訴我所有東京到達的航班之後下午5點arrive_date.date_relative arrive_date.day_name請
# -1.0
# 4.0
# arrive_date.date_relative
# new_slot: 下
# old_slot: arrive_date.date_relative
# 告訴我所有東京到達的航班之後下午5點arrive_date.date_relative arrive_date.day_name請
# 告訴我所有東京到達的航班之後下午5點下 arrive_date.day_name請
# 下
# 告訴我所有東京到達的航班之後下午5點下 arrive_date.day_name請
# 14.0
# 15.0
# arrive_date.day_name
# new_slot: 星期二
# old_slot: arrive_date.day_name
# 告訴我所有東京到達的航班之後下午5點下 arrive_date.day_name請
# 告訴我所有東京到達的航班之後下午5點下 星期二請
# 星期二
# 告訴我所有東京到達的航班之後下午5點下 星期二請
# 20.0
# 23.0
# 第 11 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從fromloc.city_name到toloc.city_name航班信息
# 從東京到toloc.city_name航班信息
# 東京
# 從東京到toloc.city_name航班信息
# 1.0
# 3.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從東京到toloc.city_name航班信息
# 從東京到東京航班信息
# 東京
# 從東京到東京航班信息
# 1.0
# 3.0
# 第 12 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 列出cost_relative航班從fromloc.city_name到toloc.city_name
# 列出最低價的航班從fromloc.city_name到toloc.city_name
# 最低價的
# 列出最低價的航班從fromloc.city_name到toloc.city_name
# 2.0
# 6.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 列出最低價的航班從fromloc.city_name到toloc.city_name
# 列出最低價的航班從東京到toloc.city_name
# 東京
# 列出最低價的航班從東京到toloc.city_name
# 9.0
# 11.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 列出最低價的航班從東京到toloc.city_name
# 列出最低價的航班從東京到東京
# 東京
# 列出最低價的航班從東京到東京
# 9.0
# 11.0
# 第 13 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我想從fromloc.city_name飛到toloc.city_name
# 我想從東京飛到toloc.city_name
# 東京
# 我想從東京飛到toloc.city_name
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我想從東京飛到toloc.city_name
# 我想從東京飛到東京
# 東京
# 我想從東京飛到東京
# 3.0
# 5.0
# 第 14 筆資料
# flight_time
# new_slot: 航班資訊
# old_slot: flight_time
# 請給我flight_time從fromloc.city_name到toloc.city_name
# 請給我航班資訊從fromloc.city_name到toloc.city_name
# 航班資訊
# 請給我航班資訊從fromloc.city_name到toloc.city_name
# 3.0
# 7.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請給我航班資訊從fromloc.city_name到toloc.city_name
# 請給我航班資訊從東京到toloc.city_name
# 東京
# 請給我航班資訊從東京到toloc.city_name
# 8.0
# 10.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 請給我航班資訊從東京到toloc.city_name
# 請給我航班資訊從東京到東京
# 東京
# 請給我航班資訊從東京到東京
# 8.0
# 10.0
# 第 15 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班經stoploc.city_name從fromloc.city_name去toloc.city_name
# 什麼航班經stoploc.city_name從東京去toloc.city_name
# 東京
# 什麼航班經stoploc.city_name從東京去toloc.city_name
# 23.0
# 25.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班經stoploc.city_name從東京去toloc.city_name
# 什麼航班經stoploc.city_name從東京去東京
# 東京
# 什麼航班經stoploc.city_name從東京去東京
# 23.0
# 25.0
# stoploc.city_name
# new_slot: 首爾
# old_slot: stoploc.city_name
# 什麼航班經stoploc.city_name從東京去東京
# 什麼航班經首爾從東京去東京
# 首爾
# 什麼航班經首爾從東京去東京
# 5.0
# 7.0
# 第 16 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從fromloc.city_name到toloc.city_name depart_date.today_relative飛行
# 從東京到toloc.city_name depart_date.today_relative飛行
# 東京
# 從東京到toloc.city_name depart_date.today_relative飛行
# 1.0
# 3.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從東京到toloc.city_name depart_date.today_relative飛行
# 從東京到東京 depart_date.today_relative飛行
# 東京
# 從東京到東京 depart_date.today_relative飛行
# 1.0
# 3.0
# depart_date.today_relative
# new_slot: 今早
# old_slot: depart_date.today_relative
# 從東京到東京 depart_date.today_relative飛行
# 從東京到東京 今早飛行
# 今早
# 從東京到東京 今早飛行
# 7.0
# 9.0
# 第 17 筆資料
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# airline_name航班從fromloc.city_name到toloc.city_name
# 華信航空航班從fromloc.city_name到toloc.city_name
# 華信航空
# 華信航空航班從fromloc.city_name到toloc.city_name
# 0.0
# 4.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 華信航空航班從fromloc.city_name到toloc.city_name
# 華信航空航班從東京到toloc.city_name
# 東京
# 華信航空航班從東京到toloc.city_name
# 7.0
# 9.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 華信航空航班從東京到toloc.city_name
# 華信航空航班從東京到東京
# 東京
# 華信航空航班從東京到東京
# 7.0
# 9.0
# 第 18 筆資料
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 在depart_date.day_name我需要看到的是假fromloc.city_name所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 在星期六我需要看到的是假fromloc.city_name所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 星期六
# 在星期六我需要看到的是假fromloc.city_name所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 1.0
# 4.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 在星期六我需要看到的是假fromloc.city_name所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 在星期六我需要看到的是假東京所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 東京
# 在星期六我需要看到的是假東京所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 12.0
# 14.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 在星期六我需要看到的是假東京所有航班和到達toloc.city_name arrive_time.time_relative下午6點
# 在星期六我需要看到的是假東京所有航班和到達東京 arrive_time.time_relative下午6點
# 東京
# 在星期六我需要看到的是假東京所有航班和到達東京 arrive_time.time_relative下午6點
# 12.0
# 14.0
# arrive_time.time_relative
# new_slot: 之後
# old_slot: arrive_time.time_relative
# 在星期六我需要看到的是假東京所有航班和到達東京 arrive_time.time_relative下午6點
# 在星期六我需要看到的是假東京所有航班和到達東京 之後下午6點
# 之後
# 在星期六我需要看到的是假東京所有航班和到達東京 之後下午6點
# 24.0
# 26.0
# arrive_time.time
# new_slot: 11:00
# old_slot: arrive_time.time
# 在星期六我需要看到的是假東京所有航班和到達東京 之後下午6點
# 在星期六我需要看到的是假東京所有航班和到達東京 之後下午6點
# 11:00
# 在星期六我需要看到的是假東京所有航班和到達東京 之後下午6點
# -1.0
# 4.0
# 第 19 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 告訴我從東京到toloc.city_name所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 東京
# 告訴我從東京到toloc.city_name所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 告訴我從東京到東京所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 東京
# 告訴我從東京到東京所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 4.0
# 6.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 告訴我從東京到東京所有航班上round_trip票價cost_relative比fare_amount一個depart_date.day_name
# 告訴我從東京到東京所有航班上round_trip票價cost_relative比fare_amount一個星期六
# 星期六
# 告訴我從東京到東京所有航班上round_trip票價cost_relative比fare_amount一個星期六
# 53.0
# 56.0
# round_trip
# new_slot: 來回
# old_slot: round_trip
# 告訴我從東京到東京所有航班上round_trip票價cost_relative比fare_amount一個星期六
# 告訴我從東京到東京所有航班上來回票價cost_relative比fare_amount一個星期六
# 來回
# 告訴我從東京到東京所有航班上來回票價cost_relative比fare_amount一個星期六
# 14.0
# 16.0
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 告訴我從東京到東京所有航班上來回票價cost_relative比fare_amount一個星期六
# 告訴我從東京到東京所有航班上來回票價最低價的比fare_amount一個星期六
# 最低價的
# 告訴我從東京到東京所有航班上來回票價最低價的比fare_amount一個星期六
# 18.0
# 22.0
# fare_amount
# new_slot: 元
# old_slot: fare_amount
# 告訴我從東京到東京所有航班上來回票價最低價的比fare_amount一個星期六
# 告訴我從東京到東京所有航班上來回票價最低價的比元一個星期六
# 元
# 告訴我從東京到東京所有航班上來回票價最低價的比元一個星期六
# 23.0
# 24.0
# 第 20 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從列出的所有fromloc.city_name航班上depart_date.day_name toloc.city_name
# 從列出的所有東京航班上depart_date.day_name toloc.city_name
# 東京
# 從列出的所有東京航班上depart_date.day_name toloc.city_name
# 6.0
# 8.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從列出的所有東京航班上depart_date.day_name toloc.city_name
# 從列出的所有東京航班上depart_date.day_name 東京
# 東京
# 從列出的所有東京航班上depart_date.day_name 東京
# 6.0
# 8.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 從列出的所有東京航班上depart_date.day_name 東京
# 從列出的所有東京航班上星期六 東京
# 星期六
# 從列出的所有東京航班上星期六 東京
# 11.0
# 14.0
# 第 21 筆資料
# flight_stop
# new_slot: 轉機
# old_slot: flight_stop
# 給我從fromloc.city_name到toloc.city_name所有flight_stop上一個arrive_date.day_name到達
# 給我從fromloc.city_name到toloc.city_name所有轉機上一個arrive_date.day_name到達
# 轉機
# 給我從fromloc.city_name到toloc.city_name所有轉機上一個arrive_date.day_name到達
# 38.0
# 40.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 給我從fromloc.city_name到toloc.city_name所有轉機上一個arrive_date.day_name到達
# 給我從東京到toloc.city_name所有轉機上一個arrive_date.day_name到達
# 東京
# 給我從東京到toloc.city_name所有轉機上一個arrive_date.day_name到達
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 給我從東京到toloc.city_name所有轉機上一個arrive_date.day_name到達
# 給我從東京到東京所有轉機上一個arrive_date.day_name到達
# 東京
# 給我從東京到東京所有轉機上一個arrive_date.day_name到達
# 3.0
# 5.0
# arrive_date.day_name
# new_slot: 星期二
# old_slot: arrive_date.day_name
# 給我從東京到東京所有轉機上一個arrive_date.day_name到達
# 給我從東京到東京所有轉機上一個星期二到達
# 星期二
# 給我從東京到東京所有轉機上一個星期二到達
# 15.0
# 18.0
# 第 22 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 是什麼從fromloc.city_name到toloc.city_name離開depart_date.today_relative航班
# 是什麼從東京到toloc.city_name離開depart_date.today_relative航班
# 東京
# 是什麼從東京到toloc.city_name離開depart_date.today_relative航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 是什麼從東京到toloc.city_name離開depart_date.today_relative航班
# 是什麼從東京到東京離開depart_date.today_relative航班
# 東京
# 是什麼從東京到東京離開depart_date.today_relative航班
# 4.0
# 6.0
# depart_date.today_relative
# new_slot: 今早
# old_slot: depart_date.today_relative
# 是什麼從東京到東京離開depart_date.today_relative航班
# 是什麼從東京到東京離開今早航班
# 今早
# 是什麼從東京到東京離開今早航班
# 11.0
# 13.0
# 第 23 筆資料
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 現在我需要一個depart_date.day_name從飛行到fromloc.city_name toloc.city_name
# 現在我需要一個星期六從飛行到fromloc.city_name toloc.city_name
# 星期六
# 現在我需要一個星期六從飛行到fromloc.city_name toloc.city_name
# 7.0
# 10.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 現在我需要一個星期六從飛行到fromloc.city_name toloc.city_name
# 現在我需要一個星期六從飛行到東京 toloc.city_name
# 東京
# 現在我需要一個星期六從飛行到東京 toloc.city_name
# 14.0
# 16.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 現在我需要一個星期六從飛行到東京 toloc.city_name
# 現在我需要一個星期六從飛行到東京 東京
# 東京
# 現在我需要一個星期六從飛行到東京 東京
# 14.0
# 16.0
# 第 24 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 晚上的
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 37.0
# 40.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 什麼是東京到toloc.city_name的晚上的飛行
# 東京
# 什麼是東京到toloc.city_name的晚上的飛行
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京到toloc.city_name的晚上的飛行
# 什麼是東京到東京的晚上的飛行
# 東京
# 什麼是東京到東京的晚上的飛行
# 3.0
# 5.0
# 第 25 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 找到fromloc.city_name到toloc.city_name在stoploc.city_name停止任何飛行
# 找到東京到toloc.city_name在stoploc.city_name停止任何飛行
# 東京
# 找到東京到toloc.city_name在stoploc.city_name停止任何飛行
# 2.0
# 4.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 找到東京到toloc.city_name在stoploc.city_name停止任何飛行
# 找到東京到東京在stoploc.city_name停止任何飛行
# 東京
# 找到東京到東京在stoploc.city_name停止任何飛行
# 2.0
# 4.0
# stoploc.city_name
# new_slot: 首爾
# old_slot: stoploc.city_name
# 找到東京到東京在stoploc.city_name停止任何飛行
# 找到東京到東京在首爾停止任何飛行
# 首爾
# 找到東京到東京在首爾停止任何飛行
# 8.0
# 10.0
# 第 26 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 你有沒有從fromloc.city_name到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 你有沒有從東京到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 東京
# 你有沒有從東京到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 你有沒有從東京到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 你有沒有從東京到東京航班上depart_date.month_name depart_date.day_number
# 東京
# 你有沒有從東京到東京航班上depart_date.month_name depart_date.day_number
# 5.0
# 7.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 你有沒有從東京到東京航班上depart_date.month_name depart_date.day_number
# 你有沒有從東京到東京航班上六月 depart_date.day_number
# 六月
# 你有沒有從東京到東京航班上六月 depart_date.day_number
# 13.0
# 15.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 你有沒有從東京到東京航班上六月 depart_date.day_number
# 你有沒有從東京到東京航班上六月 十三點
# 十三點
# 你有沒有從東京到東京航班上六月 十三點
# 16.0
# 19.0
# 第 27 筆資料
# flight_stop
# new_slot: 轉機
# old_slot: flight_stop
# 告訴我從fromloc.city_name到toloc.city_name的flight_stop航班
# 告訴我從fromloc.city_name到toloc.city_name的轉機航班
# 轉機
# 告訴我從fromloc.city_name到toloc.city_name的轉機航班
# 38.0
# 40.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name的轉機航班
# 告訴我從東京到toloc.city_name的轉機航班
# 東京
# 告訴我從東京到toloc.city_name的轉機航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name的轉機航班
# 告訴我從東京到東京的轉機航班
# 東京
# 告訴我從東京到東京的轉機航班
# 4.0
# 6.0
# 第 28 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 你可以列出航班從fromloc.city_name出發，在到達toloc.city_name
# 你可以列出航班從東京出發，在到達toloc.city_name
# 東京
# 你可以列出航班從東京出發，在到達toloc.city_name
# 8.0
# 10.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 你可以列出航班從東京出發，在到達toloc.city_name
# 你可以列出航班從東京出發，在到達東京
# 東京
# 你可以列出航班從東京出發，在到達東京
# 8.0
# 10.0
# 第 29 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼是flight_mod飛行depart_time.time_relative早上8點從fromloc.city_name到toloc.city_name
# 什麼是晚上的飛行depart_time.time_relative早上8點從fromloc.city_name到toloc.city_name
# 晚上的
# 什麼是晚上的飛行depart_time.time_relative早上8點從fromloc.city_name到toloc.city_name
# 3.0
# 6.0
# depart_time.time_relative
# new_slot: 之後
# old_slot: depart_time.time_relative
# 什麼是晚上的飛行depart_time.time_relative早上8點從fromloc.city_name到toloc.city_name
# 什麼是晚上的飛行之後早上8點從fromloc.city_name到toloc.city_name
# 之後
# 什麼是晚上的飛行之後早上8點從fromloc.city_name到toloc.city_name
# 8.0
# 10.0
# depart_time.time
# new_slot: 四點
# old_slot: depart_time.time
# 什麼是晚上的飛行之後早上8點從fromloc.city_name到toloc.city_name
# 什麼是晚上的飛行之後早上8點從fromloc.city_name到toloc.city_name
# 四點
# 什麼是晚上的飛行之後早上8點從fromloc.city_name到toloc.city_name
# -1.0
# 1.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是晚上的飛行之後早上8點從fromloc.city_name到toloc.city_name
# 什麼是晚上的飛行之後早上8點從東京到toloc.city_name
# 東京
# 什麼是晚上的飛行之後早上8點從東京到toloc.city_name
# 15.0
# 17.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是晚上的飛行之後早上8點從東京到toloc.city_name
# 什麼是晚上的飛行之後早上8點從東京到東京
# 東京
# 什麼是晚上的飛行之後早上8點從東京到東京
# 15.0
# 17.0
# 第 30 筆資料
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 這stoploc.city_name depart_time.time_relative depart_time.time上airline_name和airline_name直飛航班
# 這stoploc.city_name depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 華信航空
# 這stoploc.city_name depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 62.0
# 66.0
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 這stoploc.city_name depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 這stoploc.city_name depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 華信航空
# 這stoploc.city_name depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 62.0
# 66.0
# stoploc.city_name
# new_slot: 首爾
# old_slot: stoploc.city_name
# 這stoploc.city_name depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 這首爾 depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 首爾
# 這首爾 depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 1.0
# 3.0
# depart_time.time_relative
# new_slot: 之後
# old_slot: depart_time.time_relative
# 這首爾 depart_time.time_relative depart_time.time上華信航空和華信航空直飛航班
# 這首爾 之後 depart_time.time上華信航空和華信航空直飛航班
# 之後
# 這首爾 之後 depart_time.time上華信航空和華信航空直飛航班
# 4.0
# 6.0
# depart_time.time
# new_slot: 四點
# old_slot: depart_time.time
# 這首爾 之後 depart_time.time上華信航空和華信航空直飛航班
# 這首爾 之後 四點上華信航空和華信航空直飛航班
# 四點
# 這首爾 之後 四點上華信航空和華信航空直飛航班
# 7.0
# 9.0
# 第 31 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 什麼是fromloc.city_name到toloc.city_name的cost_relative round_trip飛行
# 什麼是fromloc.city_name到toloc.city_name的最低價的 round_trip飛行
# 最低價的
# 什麼是fromloc.city_name到toloc.city_name的最低價的 round_trip飛行
# 37.0
# 41.0
# round_trip
# new_slot: 來回
# old_slot: round_trip
# 什麼是fromloc.city_name到toloc.city_name的最低價的 round_trip飛行
# 什麼是fromloc.city_name到toloc.city_name的最低價的 來回飛行
# 來回
# 什麼是fromloc.city_name到toloc.city_name的最低價的 來回飛行
# 42.0
# 44.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的最低價的 來回飛行
# 什麼是東京到toloc.city_name的最低價的 來回飛行
# 東京
# 什麼是東京到toloc.city_name的最低價的 來回飛行
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京到toloc.city_name的最低價的 來回飛行
# 什麼是東京到東京的最低價的 來回飛行
# 東京
# 什麼是東京到東京的最低價的 來回飛行
# 3.0
# 5.0
# 第 32 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 讓我從fromloc.city_name所有cost_relative票價toloc.city_name留下depart_date.day_name
# 讓我從fromloc.city_name所有最低價的票價toloc.city_name留下depart_date.day_name
# 最低價的
# 讓我從fromloc.city_name所有最低價的票價toloc.city_name留下depart_date.day_name
# 22.0
# 26.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 讓我從fromloc.city_name所有最低價的票價toloc.city_name留下depart_date.day_name
# 讓我從東京所有最低價的票價toloc.city_name留下depart_date.day_name
# 東京
# 讓我從東京所有最低價的票價toloc.city_name留下depart_date.day_name
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 讓我從東京所有最低價的票價toloc.city_name留下depart_date.day_name
# 讓我從東京所有最低價的票價東京留下depart_date.day_name
# 東京
# 讓我從東京所有最低價的票價東京留下depart_date.day_name
# 3.0
# 5.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 讓我從東京所有最低價的票價東京留下depart_date.day_name
# 讓我從東京所有最低價的票價東京留下星期六
# 星期六
# 讓我從東京所有最低價的票價東京留下星期六
# 17.0
# 20.0
# 第 33 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 什麼是fromloc.city_name的cost_relative票價toloc.city_name任何類
# 什麼是fromloc.city_name的最低價的票價toloc.city_name任何類
# 最低價的
# 什麼是fromloc.city_name的最低價的票價toloc.city_name任何類
# 21.0
# 25.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name的最低價的票價toloc.city_name任何類
# 什麼是東京的最低價的票價toloc.city_name任何類
# 東京
# 什麼是東京的最低價的票價toloc.city_name任何類
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京的最低價的票價toloc.city_name任何類
# 什麼是東京的最低價的票價東京任何類
# 東京
# 什麼是東京的最低價的票價東京任何類
# 3.0
# 5.0
# 第 34 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 給我的airline_name航班flight_mod從depart_date.today_relative到fromloc.city_name toloc.city_name
# 給我的airline_name航班晚上的從depart_date.today_relative到fromloc.city_name toloc.city_name
# 晚上的
# 給我的airline_name航班晚上的從depart_date.today_relative到fromloc.city_name toloc.city_name
# 17.0
# 20.0
# depart_date.today_relative
# new_slot: 今早
# old_slot: depart_date.today_relative
# 給我的airline_name航班晚上的從depart_date.today_relative到fromloc.city_name toloc.city_name
# 給我的airline_name航班晚上的從今早到fromloc.city_name toloc.city_name
# 今早
# 給我的airline_name航班晚上的從今早到fromloc.city_name toloc.city_name
# 21.0
# 23.0
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 給我的airline_name航班晚上的從今早到fromloc.city_name toloc.city_name
# 給我的華信航空航班晚上的從今早到fromloc.city_name toloc.city_name
# 華信航空
# 給我的華信航空航班晚上的從今早到fromloc.city_name toloc.city_name
# 3.0
# 7.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 給我的華信航空航班晚上的從今早到fromloc.city_name toloc.city_name
# 給我的華信航空航班晚上的從今早到東京 toloc.city_name
# 東京
# 給我的華信航空航班晚上的從今早到東京 toloc.city_name
# 16.0
# 18.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 給我的華信航空航班晚上的從今早到東京 toloc.city_name
# 給我的華信航空航班晚上的從今早到東京 東京
# 東京
# 給我的華信航空航班晚上的從今早到東京 東京
# 16.0
# 18.0
# 第 35 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我想從fromloc.city_name fromloc.state_code前往toloc.city_name上depart_date.month_name depart_date.day_number
# 我想從東京 fromloc.state_code前往toloc.city_name上depart_date.month_name depart_date.day_number
# 東京
# 我想從東京 fromloc.state_code前往toloc.city_name上depart_date.month_name depart_date.day_number
# 3.0
# 5.0
# fromloc.state_code
# new_slot: JP
# old_slot: fromloc.state_code
# 我想從東京 fromloc.state_code前往toloc.city_name上depart_date.month_name depart_date.day_number
# 我想從東京 JP前往toloc.city_name上depart_date.month_name depart_date.day_number
# JP
# 我想從東京 JP前往toloc.city_name上depart_date.month_name depart_date.day_number
# 6.0
# 8.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我想從東京 JP前往toloc.city_name上depart_date.month_name depart_date.day_number
# 我想從東京 JP前往東京上depart_date.month_name depart_date.day_number
# 東京
# 我想從東京 JP前往東京上depart_date.month_name depart_date.day_number
# 3.0
# 5.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 我想從東京 JP前往東京上depart_date.month_name depart_date.day_number
# 我想從東京 JP前往東京上六月 depart_date.day_number
# 六月
# 我想從東京 JP前往東京上六月 depart_date.day_number
# 13.0
# 15.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 我想從東京 JP前往東京上六月 depart_date.day_number
# 我想從東京 JP前往東京上六月 十三點
# 十三點
# 我想從東京 JP前往東京上六月 十三點
# 16.0
# 19.0
# 第 36 筆資料
# flight_stop
# new_slot: 轉機
# old_slot: flight_stop
# 找到fromloc.city_name和toloc.city_name之間的flight_stop飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 找到fromloc.city_name和toloc.city_name之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 轉機
# 找到fromloc.city_name和toloc.city_name之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 38.0
# 40.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 找到fromloc.city_name和toloc.city_name之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 找到東京和toloc.city_name之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 東京
# 找到東京和toloc.city_name之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 2.0
# 4.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 找到東京和toloc.city_name之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 找到東京和東京之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 東京
# 找到東京和東京之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 2.0
# 4.0
# arrive_time.period_of_day
# new_slot: 傍晚的
# old_slot: arrive_time.period_of_day
# 找到東京和東京之間的轉機飛行留在arrive_time.period_of_day和到達arrive_time.time_relative下午5點
# 找到東京和東京之間的轉機飛行留在傍晚的和到達arrive_time.time_relative下午5點
# 傍晚的
# 找到東京和東京之間的轉機飛行留在傍晚的和到達arrive_time.time_relative下午5點
# 16.0
# 19.0
# arrive_time.time_relative
# new_slot: 之後
# old_slot: arrive_time.time_relative
# 找到東京和東京之間的轉機飛行留在傍晚的和到達arrive_time.time_relative下午5點
# 找到東京和東京之間的轉機飛行留在傍晚的和到達之後下午5點
# 之後
# 找到東京和東京之間的轉機飛行留在傍晚的和到達之後下午5點
# 22.0
# 24.0
# arrive_time.time
# new_slot: 11:00
# old_slot: arrive_time.time
# 找到東京和東京之間的轉機飛行留在傍晚的和到達之後下午5點
# 找到東京和東京之間的轉機飛行留在傍晚的和到達之後下午5點
# 11:00
# 找到東京和東京之間的轉機飛行留在傍晚的和到達之後下午5點
# -1.0
# 4.0
# 第 37 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從fromloc.city_name到toloc.city_name depart_date.day_name depart_time.period_of_day何去何從航班
# 從東京到toloc.city_name depart_date.day_name depart_time.period_of_day何去何從航班
# 東京
# 從東京到toloc.city_name depart_date.day_name depart_time.period_of_day何去何從航班
# 1.0
# 3.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從東京到toloc.city_name depart_date.day_name depart_time.period_of_day何去何從航班
# 從東京到東京 depart_date.day_name depart_time.period_of_day何去何從航班
# 東京
# 從東京到東京 depart_date.day_name depart_time.period_of_day何去何從航班
# 1.0
# 3.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 從東京到東京 depart_date.day_name depart_time.period_of_day何去何從航班
# 從東京到東京 星期六 depart_time.period_of_day何去何從航班
# 星期六
# 從東京到東京 星期六 depart_time.period_of_day何去何從航班
# 7.0
# 10.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 從東京到東京 星期六 depart_time.period_of_day何去何從航班
# 從東京到東京 星期六 早上的何去何從航班
# 早上的
# 從東京到東京 星期六 早上的何去何從航班
# 11.0
# 14.0
# 第 38 筆資料
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 列出toloc.city_name從fromloc.city_name上arrive_date.month_name arrive_date.day_number到達的航班
# 列出東京從fromloc.city_name上arrive_date.month_name arrive_date.day_number到達的航班
# 東京
# 列出東京從fromloc.city_name上arrive_date.month_name arrive_date.day_number到達的航班
# 2.0
# 4.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 列出東京從fromloc.city_name上arrive_date.month_name arrive_date.day_number到達的航班
# 列出東京從東京上arrive_date.month_name arrive_date.day_number到達的航班
# 東京
# 列出東京從東京上arrive_date.month_name arrive_date.day_number到達的航班
# 2.0
# 4.0
# arrive_date.month_name
# new_slot: 八月
# old_slot: arrive_date.month_name
# 列出東京從東京上arrive_date.month_name arrive_date.day_number到達的航班
# 列出東京從東京上八月 arrive_date.day_number到達的航班
# 八月
# 列出東京從東京上八月 arrive_date.day_number到達的航班
# 8.0
# 10.0
# arrive_date.day_number
# new_slot: 十八號
# old_slot: arrive_date.day_number
# 列出東京從東京上八月 arrive_date.day_number到達的航班
# 列出東京從東京上八月 十八號到達的航班
# 十八號
# 列出東京從東京上八月 十八號到達的航班
# 11.0
# 14.0
# 第 39 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從列出來fromloc.city_name toloc.city_name depart_time.period_mod depart_date.day_name所有航班
# 從列出來東京 toloc.city_name depart_time.period_mod depart_date.day_name所有航班
# 東京
# 從列出來東京 toloc.city_name depart_time.period_mod depart_date.day_name所有航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從列出來東京 toloc.city_name depart_time.period_mod depart_date.day_name所有航班
# 從列出來東京 東京 depart_time.period_mod depart_date.day_name所有航班
# 東京
# 從列出來東京 東京 depart_time.period_mod depart_date.day_name所有航班
# 4.0
# 6.0
# depart_time.period_mod
# new_slot: 紅眼
# old_slot: depart_time.period_mod
# 從列出來東京 東京 depart_time.period_mod depart_date.day_name所有航班
# 從列出來東京 東京 紅眼 depart_date.day_name所有航班
# 紅眼
# 從列出來東京 東京 紅眼 depart_date.day_name所有航班
# 10.0
# 12.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 從列出來東京 東京 紅眼 depart_date.day_name所有航班
# 從列出來東京 東京 紅眼 星期六所有航班
# 星期六
# 從列出來東京 東京 紅眼 星期六所有航班
# 13.0
# 16.0
# 第 40 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請給我所有的fromloc.city_name fromloc.state_name到toloc.city_name toloc.state_name航班
# 請給我所有的東京 fromloc.state_name到toloc.city_name toloc.state_name航班
# 東京
# 請給我所有的東京 fromloc.state_name到toloc.city_name toloc.state_name航班
# 6.0
# 8.0
# fromloc.state_name
# new_slot: 韓國
# old_slot: fromloc.state_name
# 請給我所有的東京 fromloc.state_name到toloc.city_name toloc.state_name航班
# 請給我所有的東京 韓國到toloc.city_name toloc.state_name航班
# 韓國
# 請給我所有的東京 韓國到toloc.city_name toloc.state_name航班
# 9.0
# 11.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 請給我所有的東京 韓國到toloc.city_name toloc.state_name航班
# 請給我所有的東京 韓國到東京 toloc.state_name航班
# 東京
# 請給我所有的東京 韓國到東京 toloc.state_name航班
# 6.0
# 8.0
# toloc.state_name
# new_slot:
# old_slot: toloc.state_name
# 請給我所有的東京 韓國到東京 toloc.state_name航班
# 請給我所有的東京 韓國到東京 航班
#
# 請給我所有的東京 韓國到東京 航班
# 0.0
# 0.0
# 第 41 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 你有沒有從fromloc.city_name到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 你有沒有從東京到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 東京
# 你有沒有從東京到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 你有沒有從東京到toloc.city_name航班上depart_date.month_name depart_date.day_number
# 你有沒有從東京到東京航班上depart_date.month_name depart_date.day_number
# 東京
# 你有沒有從東京到東京航班上depart_date.month_name depart_date.day_number
# 5.0
# 7.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 你有沒有從東京到東京航班上depart_date.month_name depart_date.day_number
# 你有沒有從東京到東京航班上六月 depart_date.day_number
# 六月
# 你有沒有從東京到東京航班上六月 depart_date.day_number
# 13.0
# 15.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 你有沒有從東京到東京航班上六月 depart_date.day_number
# 你有沒有從東京到東京航班上六月 十三點
# 十三點
# 你有沒有從東京到東京航班上六月 十三點
# 16.0
# 19.0
# 第 42 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 你能告訴我從fromloc.city_name到toloc.city_name隨著經濟的票價航班
# 你能告訴我從東京到toloc.city_name隨著經濟的票價航班
# 東京
# 你能告訴我從東京到toloc.city_name隨著經濟的票價航班
# 6.0
# 8.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 你能告訴我從東京到toloc.city_name隨著經濟的票價航班
# 你能告訴我從東京到東京隨著經濟的票價航班
# 東京
# 你能告訴我從東京到東京隨著經濟的票價航班
# 6.0
# 8.0
# economy
# new_slot:
# old_slot: economy
# 你能告訴我從東京到東京隨著經濟的票價航班
# 你能告訴我從東京到東京隨著經濟的票價航班
#
# 你能告訴我從東京到東京隨著經濟的票價航班
# 0.0
# 0.0
# 第 43 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班從fromloc.city_name對depart_date.day_name toloc.city_name
# 什麼航班從東京對depart_date.day_name toloc.city_name
# 東京
# 什麼航班從東京對depart_date.day_name toloc.city_name
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班從東京對depart_date.day_name toloc.city_name
# 什麼航班從東京對depart_date.day_name 東京
# 東京
# 什麼航班從東京對depart_date.day_name 東京
# 5.0
# 7.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 什麼航班從東京對depart_date.day_name 東京
# 什麼航班從東京對星期六 東京
# 星期六
# 什麼航班從東京對星期六 東京
# 8.0
# 11.0
# 第 44 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 是什麼從fromloc.city_name到toloc.city_name航班
# 是什麼從東京到toloc.city_name航班
# 東京
# 是什麼從東京到toloc.city_name航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 是什麼從東京到toloc.city_name航班
# 是什麼從東京到東京航班
# 東京
# 是什麼從東京到東京航班
# 4.0
# 6.0
# 第 45 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name到達的arrive_time.time_relative上午10時的所有航班
# 告訴我從東京到toloc.city_name到達的arrive_time.time_relative上午10時的所有航班
# 東京
# 告訴我從東京到toloc.city_name到達的arrive_time.time_relative上午10時的所有航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name到達的arrive_time.time_relative上午10時的所有航班
# 告訴我從東京到東京到達的arrive_time.time_relative上午10時的所有航班
# 東京
# 告訴我從東京到東京到達的arrive_time.time_relative上午10時的所有航班
# 4.0
# 6.0
# arrive_time.time_relative
# new_slot: 之後
# old_slot: arrive_time.time_relative
# 告訴我從東京到東京到達的arrive_time.time_relative上午10時的所有航班
# 告訴我從東京到東京到達的之後上午10時的所有航班
# 之後
# 告訴我從東京到東京到達的之後上午10時的所有航班
# 12.0
# 14.0
# arrive_time.time
# new_slot: 11:00
# old_slot: arrive_time.time
# 告訴我從東京到東京到達的之後上午10時的所有航班
# 告訴我從東京到東京到達的之後上午10時的所有航班
# 11:00
# 告訴我從東京到東京到達的之後上午10時的所有航班
# -1.0
# 4.0
# 第 46 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請給我從fromloc.city_name到toloc.city_name上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 請給我從東京到toloc.city_name上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 東京
# 請給我從東京到toloc.city_name上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 請給我從東京到toloc.city_name上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 請給我從東京到東京上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 東京
# 請給我從東京到東京上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 4.0
# 6.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 請給我從東京到東京上depart_date.day_name depart_time.period_of_day和depart_date.day_name depart_time.period_of_day航班
# 請給我從東京到東京上星期六 depart_time.period_of_day和星期六 depart_time.period_of_day航班
# 星期六
# 請給我從東京到東京上星期六 depart_time.period_of_day和星期六 depart_time.period_of_day航班
# 10.0
# 13.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 請給我從東京到東京上星期六 depart_time.period_of_day和星期六 depart_time.period_of_day航班
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 早上的
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 14.0
# 17.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 星期六
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 10.0
# 13.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 早上的
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班
# 14.0
# 17.0
# 第 47 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 列出所有航班離開fromloc.city_name depart_date.day_name depart_time.period_of_day在toloc.city_name抵達
# 列出所有航班離開東京 depart_date.day_name depart_time.period_of_day在toloc.city_name抵達
# 東京
# 列出所有航班離開東京 depart_date.day_name depart_time.period_of_day在toloc.city_name抵達
# 8.0
# 10.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 列出所有航班離開東京 depart_date.day_name depart_time.period_of_day在toloc.city_name抵達
# 列出所有航班離開東京 星期六 depart_time.period_of_day在toloc.city_name抵達
# 星期六
# 列出所有航班離開東京 星期六 depart_time.period_of_day在toloc.city_name抵達
# 11.0
# 14.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 列出所有航班離開東京 星期六 depart_time.period_of_day在toloc.city_name抵達
# 列出所有航班離開東京 星期六 早上的在toloc.city_name抵達
# 早上的
# 列出所有航班離開東京 星期六 早上的在toloc.city_name抵達
# 15.0
# 18.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 列出所有航班離開東京 星期六 早上的在toloc.city_name抵達
# 列出所有航班離開東京 星期六 早上的在東京抵達
# 東京
# 列出所有航班離開東京 星期六 早上的在東京抵達
# 8.0
# 10.0
# 第 48 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼是flight_mod depart_time.period_of_day航班離開toloc.city_name fromloc.city_name
# 什麼是晚上的 depart_time.period_of_day航班離開toloc.city_name fromloc.city_name
# 晚上的
# 什麼是晚上的 depart_time.period_of_day航班離開toloc.city_name fromloc.city_name
# 3.0
# 6.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 什麼是晚上的 depart_time.period_of_day航班離開toloc.city_name fromloc.city_name
# 什麼是晚上的 早上的航班離開toloc.city_name fromloc.city_name
# 早上的
# 什麼是晚上的 早上的航班離開toloc.city_name fromloc.city_name
# 7.0
# 10.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是晚上的 早上的航班離開toloc.city_name fromloc.city_name
# 什麼是晚上的 早上的航班離開toloc.city_name 東京
# 東京
# 什麼是晚上的 早上的航班離開toloc.city_name 東京
# 30.0
# 32.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是晚上的 早上的航班離開toloc.city_name 東京
# 什麼是晚上的 早上的航班離開東京 東京
# 東京
# 什麼是晚上的 早上的航班離開東京 東京
# 14.0
# 16.0
# 第 49 筆資料
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 請列出所有航班depart_date.day_name fromloc.city_name fromloc.city_name
# 請列出所有航班星期六 fromloc.city_name fromloc.city_name
# 星期六
# 請列出所有航班星期六 fromloc.city_name fromloc.city_name
# 7.0
# 10.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請列出所有航班星期六 fromloc.city_name fromloc.city_name
# 請列出所有航班星期六 東京 東京
# 東京
# 請列出所有航班星期六 東京 東京
# 11.0
# 13.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請列出所有航班星期六 東京 東京
# 請列出所有航班星期六 東京 東京
# 東京
# 請列出所有航班星期六 東京 東京
# 11.0
# 13.0
# 第 50 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從列出來fromloc.city_name toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 從列出來東京 toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 東京
# 從列出來東京 toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從列出來東京 toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 從列出來東京 東京 depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 東京
# 從列出來東京 東京 depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 4.0
# 6.0
# depart_time.time_relative
# new_slot: 之後
# old_slot: depart_time.time_relative
# 從列出來東京 東京 depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 從列出來東京 東京 之後 depart_time.time上depart_date.day_name所有航班
# 之後
# 從列出來東京 東京 之後 depart_time.time上depart_date.day_name所有航班
# 10.0
# 12.0
# depart_time.time
# new_slot: 四點
# old_slot: depart_time.time
# 從列出來東京 東京 之後 depart_time.time上depart_date.day_name所有航班
# 從列出來東京 東京 之後 四點上depart_date.day_name所有航班
# 四點
# 從列出來東京 東京 之後 四點上depart_date.day_name所有航班
# 13.0
# 15.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 從列出來東京 東京 之後 四點上depart_date.day_name所有航班
# 從列出來東京 東京 之後 四點上星期六所有航班
# 星期六
# 從列出來東京 東京 之後 四點上星期六所有航班
# 16.0
# 19.0
# 第 51 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name flight_stop所有航班
# 告訴我從東京到toloc.city_name flight_stop所有航班
# 東京
# 告訴我從東京到toloc.city_name flight_stop所有航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name flight_stop所有航班
# 告訴我從東京到東京 flight_stop所有航班
# 東京
# 告訴我從東京到東京 flight_stop所有航班
# 4.0
# 6.0
# flight_stop
# new_slot: 轉機
# old_slot: flight_stop
# 告訴我從東京到東京 flight_stop所有航班
# 告訴我從東京到東京 轉機所有航班
# 轉機
# 告訴我從東京到東京 轉機所有航班
# 10.0
# 12.0
# 第 52 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我需要從一個fromloc.city_name飛行toloc.city_name離開depart_date.day_name depart_time.period_of_day
# 我需要從一個東京飛行toloc.city_name離開depart_date.day_name depart_time.period_of_day
# 東京
# 我需要從一個東京飛行toloc.city_name離開depart_date.day_name depart_time.period_of_day
# 6.0
# 8.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我需要從一個東京飛行toloc.city_name離開depart_date.day_name depart_time.period_of_day
# 我需要從一個東京飛行東京離開depart_date.day_name depart_time.period_of_day
# 東京
# 我需要從一個東京飛行東京離開depart_date.day_name depart_time.period_of_day
# 6.0
# 8.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 我需要從一個東京飛行東京離開depart_date.day_name depart_time.period_of_day
# 我需要從一個東京飛行東京離開星期六 depart_time.period_of_day
# 星期六
# 我需要從一個東京飛行東京離開星期六 depart_time.period_of_day
# 14.0
# 17.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 我需要從一個東京飛行東京離開星期六 depart_time.period_of_day
# 我需要從一個東京飛行東京離開星期六 早上的
# 早上的
# 我需要從一個東京飛行東京離開星期六 早上的
# 18.0
# 21.0
# 第 53 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我想訂一張從fromloc.city_name航班的toloc.city_name上depart_date.month_name depart_date.day_number
# 我想訂一張從東京航班的toloc.city_name上depart_date.month_name depart_date.day_number
# 東京
# 我想訂一張從東京航班的toloc.city_name上depart_date.month_name depart_date.day_number
# 6.0
# 8.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我想訂一張從東京航班的toloc.city_name上depart_date.month_name depart_date.day_number
# 我想訂一張從東京航班的東京上depart_date.month_name depart_date.day_number
# 東京
# 我想訂一張從東京航班的東京上depart_date.month_name depart_date.day_number
# 6.0
# 8.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 我想訂一張從東京航班的東京上depart_date.month_name depart_date.day_number
# 我想訂一張從東京航班的東京上六月 depart_date.day_number
# 六月
# 我想訂一張從東京航班的東京上六月 depart_date.day_number
# 14.0
# 16.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 我想訂一張從東京航班的東京上六月 depart_date.day_number
# 我想訂一張從東京航班的東京上六月 十三點
# 十三點
# 我想訂一張從東京航班的東京上六月 十三點
# 17.0
# 20.0
# 第 54 筆資料
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 告訴我的airline_name toloc.city_name在depart_time.period_of_day航班
# 告訴我的華信航空 toloc.city_name在depart_time.period_of_day航班
# 華信航空
# 告訴我的華信航空 toloc.city_name在depart_time.period_of_day航班
# 4.0
# 8.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我的華信航空 toloc.city_name在depart_time.period_of_day航班
# 告訴我的華信航空 東京在depart_time.period_of_day航班
# 東京
# 告訴我的華信航空 東京在depart_time.period_of_day航班
# 9.0
# 11.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 告訴我的華信航空 東京在depart_time.period_of_day航班
# 告訴我的華信航空 東京在早上的航班
# 早上的
# 告訴我的華信航空 東京在早上的航班
# 12.0
# 15.0
# 第 55 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼才是從fromloc.city_name的flight_mod飛行toloc.city_name
# 什麼才是從fromloc.city_name的晚上的飛行toloc.city_name
# 晚上的
# 什麼才是從fromloc.city_name的晚上的飛行toloc.city_name
# 23.0
# 26.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼才是從fromloc.city_name的晚上的飛行toloc.city_name
# 什麼才是從東京的晚上的飛行toloc.city_name
# 東京
# 什麼才是從東京的晚上的飛行toloc.city_name
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼才是從東京的晚上的飛行toloc.city_name
# 什麼才是從東京的晚上的飛行東京
# 東京
# 什麼才是從東京的晚上的飛行東京
# 5.0
# 7.0
# 第 56 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我要飛fromloc.city_name到toloc.city_name上depart_date.month_name depart_date.day_number
# 我要飛東京到toloc.city_name上depart_date.month_name depart_date.day_number
# 東京
# 我要飛東京到toloc.city_name上depart_date.month_name depart_date.day_number
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我要飛東京到toloc.city_name上depart_date.month_name depart_date.day_number
# 我要飛東京到東京上depart_date.month_name depart_date.day_number
# 東京
# 我要飛東京到東京上depart_date.month_name depart_date.day_number
# 3.0
# 5.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 我要飛東京到東京上depart_date.month_name depart_date.day_number
# 我要飛東京到東京上六月 depart_date.day_number
# 六月
# 我要飛東京到東京上六月 depart_date.day_number
# 9.0
# 11.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 我要飛東京到東京上六月 depart_date.day_number
# 我要飛東京到東京上六月 十三點
# 十三點
# 我要飛東京到東京上六月 十三點
# 12.0
# 15.0
# 第 57 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我想從fromloc.city_name前往toloc.city_name
# 我想從東京前往toloc.city_name
# 東京
# 我想從東京前往toloc.city_name
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我想從東京前往toloc.city_name
# 我想從東京前往東京
# 東京
# 我想從東京前往東京
# 3.0
# 5.0
# 第 58 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班從fromloc.city_name去toloc.city_name depart_time.time_relative下午2點
# 什麼航班從東京去toloc.city_name depart_time.time_relative下午2點
# 東京
# 什麼航班從東京去toloc.city_name depart_time.time_relative下午2點
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班從東京去toloc.city_name depart_time.time_relative下午2點
# 什麼航班從東京去東京 depart_time.time_relative下午2點
# 東京
# 什麼航班從東京去東京 depart_time.time_relative下午2點
# 5.0
# 7.0
# depart_time.time_relative
# new_slot: 之後
# old_slot: depart_time.time_relative
# 什麼航班從東京去東京 depart_time.time_relative下午2點
# 什麼航班從東京去東京 之後下午2點
# 之後
# 什麼航班從東京去東京 之後下午2點
# 11.0
# 13.0
# depart_time.time
# new_slot: 四點
# old_slot: depart_time.time
# 什麼航班從東京去東京 之後下午2點
# 什麼航班從東京去東京 之後下午2點
# 四點
# 什麼航班從東京去東京 之後下午2點
# -1.0
# 1.0
# 第 59 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我想看到fromloc.city_name到toloc.city_name所有航班
# 我想看到東京到toloc.city_name所有航班
# 東京
# 我想看到東京到toloc.city_name所有航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我想看到東京到toloc.city_name所有航班
# 我想看到東京到東京所有航班
# 東京
# 我想看到東京到東京所有航班
# 4.0
# 6.0
# 第 60 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從fromloc.city_name fromloc.state_code到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# 從東京 fromloc.state_code到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# 東京
# 從東京 fromloc.state_code到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# 1.0
# 3.0
# fromloc.state_code
# new_slot: JP
# old_slot: fromloc.state_code
# 從東京 fromloc.state_code到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# 從東京 JP到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# JP
# 從東京 JP到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從東京 JP到toloc.city_name所有航班depart_date.month_name depart_date.day_number
# 從東京 JP到東京所有航班depart_date.month_name depart_date.day_number
# 東京
# 從東京 JP到東京所有航班depart_date.month_name depart_date.day_number
# 1.0
# 3.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 從東京 JP到東京所有航班depart_date.month_name depart_date.day_number
# 從東京 JP到東京所有航班六月 depart_date.day_number
# 六月
# 從東京 JP到東京所有航班六月 depart_date.day_number
# 13.0
# 15.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 從東京 JP到東京所有航班六月 depart_date.day_number
# 從東京 JP到東京所有航班六月 十三點
# 十三點
# 從東京 JP到東京所有航班六月 十三點
# 16.0
# 19.0
# 第 61 筆資料
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 告訴我從fromloc.city_name到toloc.city_name的depart_time.period_of_day航班
# 告訴我從fromloc.city_name到toloc.city_name的早上的航班
# 早上的
# 告訴我從fromloc.city_name到toloc.city_name的早上的航班
# 38.0
# 41.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name的早上的航班
# 告訴我從東京到toloc.city_name的早上的航班
# 東京
# 告訴我從東京到toloc.city_name的早上的航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name的早上的航班
# 告訴我從東京到東京的早上的航班
# 東京
# 告訴我從東京到東京的早上的航班
# 4.0
# 6.0
# 第 62 筆資料
# flight_stop
# new_slot: 轉機
# old_slot: flight_stop
# 需要多少費用從fromloc.city_name飛flight_stop到toloc.city_name上airline_name
# 需要多少費用從fromloc.city_name飛轉機到toloc.city_name上airline_name
# 轉機
# 需要多少費用從fromloc.city_name飛轉機到toloc.city_name上airline_name
# 25.0
# 27.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 需要多少費用從fromloc.city_name飛轉機到toloc.city_name上airline_name
# 需要多少費用從東京飛轉機到toloc.city_name上airline_name
# 東京
# 需要多少費用從東京飛轉機到toloc.city_name上airline_name
# 7.0
# 9.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 需要多少費用從東京飛轉機到toloc.city_name上airline_name
# 需要多少費用從東京飛轉機到東京上airline_name
# 東京
# 需要多少費用從東京飛轉機到東京上airline_name
# 7.0
# 9.0
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 需要多少費用從東京飛轉機到東京上airline_name
# 需要多少費用從東京飛轉機到東京上華信航空
# 華信航空
# 需要多少費用從東京飛轉機到東京上華信航空
# 16.0
# 20.0
# 第 63 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 給我從fromloc.city_name到toloc.city_name toloc.state_code航班的depart_date.month_name depart_date.day_number
# 給我從東京到toloc.city_name toloc.state_code航班的depart_date.month_name depart_date.day_number
# 東京
# 給我從東京到toloc.city_name toloc.state_code航班的depart_date.month_name depart_date.day_number
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 給我從東京到toloc.city_name toloc.state_code航班的depart_date.month_name depart_date.day_number
# 給我從東京到東京 toloc.state_code航班的depart_date.month_name depart_date.day_number
# 東京
# 給我從東京到東京 toloc.state_code航班的depart_date.month_name depart_date.day_number
# 3.0
# 5.0
# toloc.state_code
# new_slot:
# old_slot: toloc.state_code
# 給我從東京到東京 toloc.state_code航班的depart_date.month_name depart_date.day_number
# 給我從東京到東京 航班的depart_date.month_name depart_date.day_number
#
# 給我從東京到東京 航班的depart_date.month_name depart_date.day_number
# 0.0
# 0.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 給我從東京到東京 航班的depart_date.month_name depart_date.day_number
# 給我從東京到東京 航班的六月 depart_date.day_number
# 六月
# ...
# 13.0
# 15.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 有沒有在一個華信航空航班從東京要toloc.city_name上depart_date.month_name depart_date.day_number
# 有沒有在一個華信航空航班從東京要東京上depart_date.month_name depart_date.day_number
# 東京
# 有沒有在一個華信航空航班從東京要東京上depart_date.month_name depart_date.day_number
# 13.0
# 15.0
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 有沒有在一個華信航空航班從東京要東京上depart_date.month_name depart_date.day_number
# 有沒有在一個華信航空航班從東京要東京上六月 depart_date.day_number
# 六月
# 有沒有在一個華信航空航班從東京要東京上六月 depart_date.day_number
# 19.0
# 21.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 有沒有在一個華信航空航班從東京要東京上六月 depart_date.day_number
# 有沒有在一個華信航空航班從東京要東京上六月 十三點
# 十三點
# 有沒有在一個華信航空航班從東京要東京上六月 十三點
# 22.0
# 25.0
# 第 79 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我要飛從fromloc.city_name到toloc.city_name
# 我要飛從東京到toloc.city_name
# 東京
# 我要飛從東京到toloc.city_name
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我要飛從東京到toloc.city_name
# 我要飛從東京到東京
# 東京
# 我要飛從東京到東京
# 4.0
# 6.0
# 第 80 筆資料
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# depart_time.period_of_day fromloc.city_name和toloc.city_name之間depart_time.period_of_day航班
# 早上的 fromloc.city_name和toloc.city_name之間早上的航班
# 早上的
# 早上的 fromloc.city_name和toloc.city_name之間早上的航班
# 0.0
# 3.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 早上的 fromloc.city_name和toloc.city_name之間早上的航班
# 早上的 fromloc.city_name和toloc.city_name之間早上的航班
# 早上的
# 早上的 fromloc.city_name和toloc.city_name之間早上的航班
# 0.0
# 3.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 早上的 fromloc.city_name和toloc.city_name之間早上的航班
# 早上的 東京和toloc.city_name之間早上的航班
# 東京
# 早上的 東京和toloc.city_name之間早上的航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 早上的 東京和toloc.city_name之間早上的航班
# 早上的 東京和東京之間早上的航班
# 東京
# 早上的 東京和東京之間早上的航班
# 4.0
# 6.0
# 第 81 筆資料
# depart_date.month_name
# new_slot: 六月
# old_slot: depart_date.month_name
# 在depart_date.month_name depart_date.day_number我想從fromloc.city_name預訂航班到toloc.city_name
# 在六月 depart_date.day_number我想從fromloc.city_name預訂航班到toloc.city_name
# 六月
# 在六月 depart_date.day_number我想從fromloc.city_name預訂航班到toloc.city_name
# 1.0
# 3.0
# depart_date.day_number
# new_slot: 十三點
# old_slot: depart_date.day_number
# 在六月 depart_date.day_number我想從fromloc.city_name預訂航班到toloc.city_name
# 在六月 十三點我想從fromloc.city_name預訂航班到toloc.city_name
# 十三點
# 在六月 十三點我想從fromloc.city_name預訂航班到toloc.city_name
# 4.0
# 7.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 在六月 十三點我想從fromloc.city_name預訂航班到toloc.city_name
# 在六月 十三點我想從東京預訂航班到toloc.city_name
# 東京
# 在六月 十三點我想從東京預訂航班到toloc.city_name
# 10.0
# 12.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 在六月 十三點我想從東京預訂航班到toloc.city_name
# 在六月 十三點我想從東京預訂航班到東京
# 東京
# 在六月 十三點我想從東京預訂航班到東京
# 10.0
# 12.0
# 第 82 筆資料
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 什麼depart_time.period_of_day航班fromloc.city_name和toloc.city_name之間可用
# 什麼早上的航班fromloc.city_name和toloc.city_name之間可用
# 早上的
# 什麼早上的航班fromloc.city_name和toloc.city_name之間可用
# 2.0
# 5.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼早上的航班fromloc.city_name和toloc.city_name之間可用
# 什麼早上的航班東京和toloc.city_name之間可用
# 東京
# 什麼早上的航班東京和toloc.city_name之間可用
# 7.0
# 9.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼早上的航班東京和toloc.city_name之間可用
# 什麼早上的航班東京和東京之間可用
# 東京
# 什麼早上的航班東京和東京之間可用
# 7.0
# 9.0
# 第 83 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 晚上的
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 37.0
# 40.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的晚上的飛行
# 什麼是東京到toloc.city_name的晚上的飛行
# 東京
# 什麼是東京到toloc.city_name的晚上的飛行
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京到toloc.city_name的晚上的飛行
# 什麼是東京到東京的晚上的飛行
# 東京
# 什麼是東京到東京的晚上的飛行
# 3.0
# 5.0
# 第 84 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 從列出來fromloc.city_name toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 從列出來東京 toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 東京
# 從列出來東京 toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 從列出來東京 toloc.city_name depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 從列出來東京 東京 depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 東京
# 從列出來東京 東京 depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 4.0
# 6.0
# depart_time.time_relative
# new_slot: 之後
# old_slot: depart_time.time_relative
# 從列出來東京 東京 depart_time.time_relative depart_time.time上depart_date.day_name所有航班
# 從列出來東京 東京 之後 depart_time.time上depart_date.day_name所有航班
# 之後
# 從列出來東京 東京 之後 depart_time.time上depart_date.day_name所有航班
# 10.0
# 12.0
# depart_time.time
# new_slot: 四點
# old_slot: depart_time.time
# 從列出來東京 東京 之後 depart_time.time上depart_date.day_name所有航班
# 從列出來東京 東京 之後 四點上depart_date.day_name所有航班
# 四點
# 從列出來東京 東京 之後 四點上depart_date.day_name所有航班
# 13.0
# 15.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 從列出來東京 東京 之後 四點上depart_date.day_name所有航班
# 從列出來東京 東京 之後 四點上星期六所有航班
# 星期六
# 從列出來東京 東京 之後 四點上星期六所有航班
# 16.0
# 19.0
# 第 85 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 什麼是flight_mod航班從fromloc.city_name離開去toloc.city_name
# 什麼是晚上的航班從fromloc.city_name離開去toloc.city_name
# 晚上的
# 什麼是晚上的航班從fromloc.city_name離開去toloc.city_name
# 3.0
# 6.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是晚上的航班從fromloc.city_name離開去toloc.city_name
# 什麼是晚上的航班從東京離開去toloc.city_name
# 東京
# 什麼是晚上的航班從東京離開去toloc.city_name
# 9.0
# 11.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是晚上的航班從東京離開去toloc.city_name
# 什麼是晚上的航班從東京離開去東京
# 東京
# 什麼是晚上的航班從東京離開去東京
# 9.0
# 11.0
# 第 86 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 我需要從fromloc.city_name飛往toloc.city_name這個depart_date.day_name
# 我需要從東京飛往toloc.city_name這個depart_date.day_name
# 東京
# 我需要從東京飛往toloc.city_name這個depart_date.day_name
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 我需要從東京飛往toloc.city_name這個depart_date.day_name
# 我需要從東京飛往東京這個depart_date.day_name
# 東京
# 我需要從東京飛往東京這個depart_date.day_name
# 4.0
# 6.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 我需要從東京飛往東京這個depart_date.day_name
# 我需要從東京飛往東京這個星期六
# 星期六
# 我需要從東京飛往東京這個星期六
# 12.0
# 15.0
# 第 87 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班從fromloc.city_name離開toloc.city_name在depart_time.period_of_day
# 什麼航班從東京離開toloc.city_name在depart_time.period_of_day
# 東京
# 什麼航班從東京離開toloc.city_name在depart_time.period_of_day
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班從東京離開toloc.city_name在depart_time.period_of_day
# 什麼航班從東京離開東京在depart_time.period_of_day
# 東京
# 什麼航班從東京離開東京在depart_time.period_of_day
# 5.0
# 7.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 什麼航班從東京離開東京在depart_time.period_of_day
# 什麼航班從東京離開東京在早上的
# 早上的
# 什麼航班從東京離開東京在早上的
# 12.0
# 15.0
# 第 88 筆資料
# flight_stop
# new_slot: 轉機
# old_slot: flight_stop
# 什麼flight_stop fromloc.city_name和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 什麼轉機 fromloc.city_name和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 轉機
# 什麼轉機 fromloc.city_name和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 2.0
# 4.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼轉機 fromloc.city_name和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 什麼轉機 東京和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 東京
# 什麼轉機 東京和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼轉機 東京和toloc.city_name之間的航班??抵達arrive_time.time_relative arrive_time.time
# 什麼轉機 東京和東京之間的航班??抵達arrive_time.time_relative arrive_time.time
# 東京
# 什麼轉機 東京和東京之間的航班??抵達arrive_time.time_relative arrive_time.time
# 5.0
# 7.0
# arrive_time.time_relative
# new_slot: 之後
# old_slot: arrive_time.time_relative
# 什麼轉機 東京和東京之間的航班??抵達arrive_time.time_relative arrive_time.time
# 什麼轉機 東京和東京之間的航班??抵達之後 arrive_time.time
# 之後
# 什麼轉機 東京和東京之間的航班??抵達之後 arrive_time.time
# 19.0
# 21.0
# arrive_time.time
# new_slot: 11:00
# old_slot: arrive_time.time
# 什麼轉機 東京和東京之間的航班??抵達之後 arrive_time.time
# 什麼轉機 東京和東京之間的航班??抵達之後 11:00
# 11:00
# 什麼轉機 東京和東京之間的航班??抵達之後 11:00
# 22.0
# 27.0
# 第 89 筆資料
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 什麼才是從fromloc.city_name到toloc.city_name的airline_name次航班票價
# 什麼才是從fromloc.city_name到toloc.city_name的華信航空次航班票價
# 華信航空
# 什麼才是從fromloc.city_name到toloc.city_name的華信航空次航班票價
# 39.0
# 43.0
# flight_number
# new_slot: CI0150
# old_slot: flight_number
# 什麼才是從fromloc.city_name到toloc.city_name的華信航空次航班票價
# 什麼才是從fromloc.city_name到toloc.city_name的華信航空次航班票價
# CI0150
# 什麼才是從fromloc.city_name到toloc.city_name的華信航空次航班票價
# -1.0
# 5.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼才是從fromloc.city_name到toloc.city_name的華信航空次航班票價
# 什麼才是從東京到toloc.city_name的華信航空次航班票價
# 東京
# 什麼才是從東京到toloc.city_name的華信航空次航班票價
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼才是從東京到toloc.city_name的華信航空次航班票價
# 什麼才是從東京到東京的華信航空次航班票價
# 東京
# 什麼才是從東京到東京的華信航空次航班票價
# 5.0
# 7.0
# 第 90 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班從fromloc.city_name去toloc.city_name depart_time.time_relative下午5點
# 什麼航班從東京去toloc.city_name depart_time.time_relative下午5點
# 東京
# 什麼航班從東京去toloc.city_name depart_time.time_relative下午5點
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班從東京去toloc.city_name depart_time.time_relative下午5點
# 什麼航班從東京去東京 depart_time.time_relative下午5點
# 東京
# 什麼航班從東京去東京 depart_time.time_relative下午5點
# 5.0
# 7.0
# depart_time.time_relative
# new_slot: 之後
# old_slot: depart_time.time_relative
# 什麼航班從東京去東京 depart_time.time_relative下午5點
# 什麼航班從東京去東京 之後下午5點
# 之後
# 什麼航班從東京去東京 之後下午5點
# 11.0
# 13.0
# depart_time.time
# new_slot: 四點
# old_slot: depart_time.time
# 什麼航班從東京去東京 之後下午5點
# 什麼航班從東京去東京 之後下午5點
# 四點
# 什麼航班從東京去東京 之後下午5點
# -1.0
# 1.0
# 第 91 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 哪些航班從有到fromloc.city_name toloc.city_name
# 哪些航班從有到東京 toloc.city_name
# 東京
# 哪些航班從有到東京 toloc.city_name
# 7.0
# 9.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 哪些航班從有到東京 toloc.city_name
# 哪些航班從有到東京 東京
# 東京
# 哪些航班從有到東京 東京
# 7.0
# 9.0
# 第 92 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 你有沒有從fromloc.city_name到toloc.city_name toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 你有沒有從東京到toloc.city_name toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 東京
# 你有沒有從東京到toloc.city_name toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 你有沒有從東京到toloc.city_name toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 你有沒有從東京到東京 toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 東京
# 你有沒有從東京到東京 toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 5.0
# 7.0
# toloc.state_name
# new_slot:
# old_slot: toloc.state_name
# 你有沒有從東京到東京 toloc.state_name depart_date.date_relative depart_date.day_name飛行
# 你有沒有從東京到東京  depart_date.date_relative depart_date.day_name飛行
#
# 你有沒有從東京到東京  depart_date.date_relative depart_date.day_name飛行
# 0.0
# 0.0
# depart_date.date_relative
# new_slot: 下(next)
# old_slot: depart_date.date_relative
# 你有沒有從東京到東京  depart_date.date_relative depart_date.day_name飛行
# 你有沒有從東京到東京  下(next) depart_date.day_name飛行
# 下(next)
# 你有沒有從東京到東京  下(next) depart_date.day_name飛行
# 12.0
# 19.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 你有沒有從東京到東京  下(next) depart_date.day_name飛行
# 你有沒有從東京到東京  下(next) 星期六飛行
# 星期六
# 你有沒有從東京到東京  下(next) 星期六飛行
# 20.0
# 23.0
# 第 93 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼航班從fromloc.city_name去上depart_date.day_name toloc.city_name toloc.state_code
# 什麼航班從東京去上depart_date.day_name toloc.city_name toloc.state_code
# 東京
# 什麼航班從東京去上depart_date.day_name toloc.city_name toloc.state_code
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼航班從東京去上depart_date.day_name toloc.city_name toloc.state_code
# 什麼航班從東京去上depart_date.day_name 東京 toloc.state_code
# 東京
# 什麼航班從東京去上depart_date.day_name 東京 toloc.state_code
# 5.0
# 7.0
# toloc.state_code
# new_slot:
# old_slot: toloc.state_code
# 什麼航班從東京去上depart_date.day_name 東京 toloc.state_code
# 什麼航班從東京去上depart_date.day_name 東京
#
# 什麼航班從東京去上depart_date.day_name 東京
# 0.0
# 0.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 什麼航班從東京去上depart_date.day_name 東京
# 什麼航班從東京去上星期六 東京
# 星期六
# 什麼航班從東京去上星期六 東京
# 9.0
# 12.0
# 第 94 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 請安排從fromloc.city_name對我來說是飛行到airline_name toloc.city_name
# 請安排從東京對我來說是飛行到airline_name toloc.city_name
# 東京
# 請安排從東京對我來說是飛行到airline_name toloc.city_name
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 請安排從東京對我來說是飛行到airline_name toloc.city_name
# 請安排從東京對我來說是飛行到airline_name 東京
# 東京
# 請安排從東京對我來說是飛行到airline_name 東京
# 4.0
# 6.0
# airline_name
# new_slot: 華信航空
# old_slot: airline_name
# 請安排從東京對我來說是飛行到airline_name 東京
# 請安排從東京對我來說是飛行到華信航空 東京
# 華信航空
# 請安排從東京對我來說是飛行到華信航空 東京
# 14.0
# 18.0
# 第 95 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name航班
# 告訴我從東京到toloc.city_name上depart_date.day_name航班
# 東京
# 告訴我從東京到toloc.city_name上depart_date.day_name航班
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name上depart_date.day_name航班
# 告訴我從東京到東京上depart_date.day_name航班
# 東京
# 告訴我從東京到東京上depart_date.day_name航班
# 4.0
# 6.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 告訴我從東京到東京上depart_date.day_name航班
# 告訴我從東京到東京上星期六航班
# 星期六
# 告訴我從東京到東京上星期六航班
# 10.0
# 13.0
# 第 96 筆資料
# cost_relative
# new_slot: 最低價的
# old_slot: cost_relative
# 什麼是fromloc.city_name和toloc.city_name之間的cost_relative機票
# 什麼是fromloc.city_name和toloc.city_name之間的最低價的機票
# 最低價的
# 什麼是fromloc.city_name和toloc.city_name之間的最低價的機票
# 39.0
# 43.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 什麼是fromloc.city_name和toloc.city_name之間的最低價的機票
# 什麼是東京和toloc.city_name之間的最低價的機票
# 東京
# 什麼是東京和toloc.city_name之間的最低價的機票
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 什麼是東京和toloc.city_name之間的最低價的機票
# 什麼是東京和東京之間的最低價的機票
# 東京
# 什麼是東京和東京之間的最低價的機票
# 3.0
# 5.0
# 第 97 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 需要從fromloc.city_name到toloc.city_name飛行
# 需要從東京到toloc.city_name飛行
# 東京
# 需要從東京到toloc.city_name飛行
# 3.0
# 5.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 需要從東京到toloc.city_name飛行
# 需要從東京到東京飛行
# 東京
# 需要從東京到東京飛行
# 3.0
# 5.0
# 第 98 筆資料
# flight_mod
# new_slot: 晚上的
# old_slot: flight_mod
# 告訴我從fromloc.city_name到toloc.city_name的flight_mod飛行
# 告訴我從fromloc.city_name到toloc.city_name的晚上的飛行
# 晚上的
# 告訴我從fromloc.city_name到toloc.city_name的晚上的飛行
# 38.0
# 41.0
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name的晚上的飛行
# 告訴我從東京到toloc.city_name的晚上的飛行
# 東京
# 告訴我從東京到toloc.city_name的晚上的飛行
# 4.0
# 6.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 告訴我從東京到toloc.city_name的晚上的飛行
# 告訴我從東京到東京的晚上的飛行
# 東京
# 告訴我從東京到東京的晚上的飛行
# 4.0
# 6.0
# 第 99 筆資料
# fromloc.city_name
# new_slot: 東京
# old_slot: fromloc.city_name
# 你有沒有從fromloc.city_name到toloc.city_name上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 你有沒有從東京到toloc.city_name上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 東京
# 你有沒有從東京到toloc.city_name上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 5.0
# 7.0
# toloc.city_name
# new_slot: 東京
# old_slot: toloc.city_name
# 你有沒有從東京到toloc.city_name上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 你有沒有從東京到東京上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 東京
# 你有沒有從東京到東京上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 5.0
# 7.0
# depart_date.day_name
# new_slot: 星期六
# old_slot: depart_date.day_name
# 你有沒有從東京到東京上depart_date.date_relative週depart_date.day_name在depart_time.period_of_day任何航班
# 你有沒有從東京到東京上depart_date.date_relative週星期六在depart_time.period_of_day任何航班
# 星期六
# 你有沒有從東京到東京上depart_date.date_relative週星期六在depart_time.period_of_day任何航班
# 37.0
# 40.0
# depart_date.date_relative
# new_slot: 下(next)
# old_slot: depart_date.date_relative
# 你有沒有從東京到東京上depart_date.date_relative週星期六在depart_time.period_of_day任何航班
# 你有沒有從東京到東京上下(next)週星期六在depart_time.period_of_day任何航班
# 下(next)
# 你有沒有從東京到東京上下(next)週星期六在depart_time.period_of_day任何航班
# 11.0
# 18.0
# depart_time.period_of_day
# new_slot: 早上的
# old_slot: depart_time.period_of_day
# 你有沒有從東京到東京上下(next)週星期六在depart_time.period_of_day任何航班
# 你有沒有從東京到東京上下(next)週星期六在早上的任何航班
# 早上的
# 你有沒有從東京到東京上下(next)週星期六在早上的任何航班
# 23.0
# 26.0

# %%
os.getcwd()
data.to_csv('output2.csv',encoding="MS950")

# %%
with open('output.csv','w',newline='',encoding="MS950") as csvfile:
  writer = csv.writer(csvfile, delimiter='\t')
  for i in range(0,len(data)-1):
    s=''
    for j in range(len(data.iloc[i,])):
      if(j==len(data.iloc[i,])-1):
        c=data.iloc[i,j]
        if(str(c)=='nan'):
          s=s+''
        else:
          s=s+str(c)
          
      else:
        c=data.iloc[i,j]
        if(str(c)=='nan'):
          s=s+''
        elif(str(data.iloc[i,j+1])=='nan'):
          s=s+str(c)
          #s.join(c)
        else:
          s=s+str(c)+','
          #s.join(c)+','
    print(s)
    #writer.writerow(s)
# Out:
# 什麼是東京到東京的晚上的飛行,flight,37.0,40.0,晚上的,flight_mod,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 什麼航班資訊確實華信航空從出發到東京 東京,flight_time,2.0,6.0,航班資訊,flight_time,8.0,12.0,華信航空,airline_name,16.0,18.0,東京,fromloc.city_name,16.0,18.0,東京,toloc.city_name
# 我想要看到東京到東京航班,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name
# 什麼是東京到東京的最低價的票價,airfare,37.0,41.0,最低價的,cost_relative,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 列出所有從東京到東京航班,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name
# 請出示機票東京到達從東京,flight,5.0,7.0,東京,toloc.city_name,5.0,7.0,東京,fromloc.city_name
# 什麼航班你有從東京到東京,flight,7.0,9.0,東京,fromloc.city_name,7.0,9.0,東京,toloc.city_name
# 從東京到東京 航班,flight,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name,0.0,0.0,,toloc.state_code
# 給我從東京的最低價的航班上星期六 東京,flight,21.0,25.0,最低價的,cost_relative,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name,13.0,16.0,星期六,depart_date.day_name
# 清單每天從東京到東京與頭等艙航班,flight,2.0,4.0,每天,flight_days,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,11.0,14.0,頭等艙,class_type
# 告訴我所有東京到達的航班之後下午5點下 星期二請,flight,5.0,7.0,東京,toloc.city_name,12.0,14.0,之後,arrive_time.time_relative,-1.0,4.0,11:00,arrive_time.time,14.0,15.0,下,arrive_date.date_relative,20.0,23.0,星期二,arrive_date.day_name
# 從東京到東京航班信息,flight,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name
# 列出最低價的航班從東京到東京,flight,2.0,6.0,最低價的,cost_relative,9.0,11.0,東京,fromloc.city_name,9.0,11.0,東京,toloc.city_name
# 我想從東京飛到東京,flight,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 請給我航班資訊從東京到東京,flight,3.0,7.0,航班資訊,flight_time,8.0,10.0,東京,fromloc.city_name,8.0,10.0,東京,toloc.city_name
# 什麼航班經首爾從東京去東京,flight,23.0,25.0,東京,fromloc.city_name,23.0,25.0,東京,toloc.city_name,5.0,7.0,首爾,stoploc.city_name
# 從東京到東京 今早飛行,flight,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name,7.0,9.0,今早,depart_date.today_relative
# 華信航空航班從東京到東京,flight,0.0,4.0,華信航空,airline_name,7.0,9.0,東京,fromloc.city_name,7.0,9.0,東京,toloc.city_name
# 在星期六我需要看到的是假東京所有航班和到達東京 之後下午6點,flight,1.0,4.0,星期六,depart_date.day_name,12.0,14.0,東京,fromloc.city_name,12.0,14.0,東京,toloc.city_name,24.0,26.0,之後,arrive_time.time_relative,-1.0,4.0,11:00,arrive_time.time
# 告訴我從東京到東京所有航班上來回票價最低價的比元一個星期六,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,53.0,56.0,星期六,depart_date.day_name,14.0,16.0,來回,round_trip,18.0,22.0,最低價的,cost_relative,23.0,24.0,元,fare_amount
# 從列出的所有東京航班上星期六 東京,flight,6.0,8.0,東京,fromloc.city_name,6.0,8.0,東京,toloc.city_name,11.0,14.0,星期六,depart_date.day_name
# 給我從東京到東京所有轉機上一個星期二到達,flight,38.0,40.0,轉機,flight_stop,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name,15.0,18.0,星期二,arrive_date.day_name
# 是什麼從東京到東京離開今早航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,11.0,13.0,今早,depart_date.today_relative
# 現在我需要一個星期六從飛行到東京 東京,flight,7.0,10.0,星期六,depart_date.day_name,14.0,16.0,東京,fromloc.city_name,14.0,16.0,東京,toloc.city_name
# 什麼是東京到東京的晚上的飛行,flight,37.0,40.0,晚上的,flight_mod,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 找到東京到東京在首爾停止任何飛行,flight,2.0,4.0,東京,fromloc.city_name,2.0,4.0,東京,toloc.city_name,8.0,10.0,首爾,stoploc.city_name
# 你有沒有從東京到東京航班上六月 十三點,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,13.0,15.0,六月,depart_date.month_name,16.0,19.0,十三點,depart_date.day_number
# 告訴我從東京到東京的轉機航班,flight,38.0,40.0,轉機,flight_stop,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 你可以列出航班從東京出發，在到達東京,flight,8.0,10.0,東京,fromloc.city_name,8.0,10.0,東京,toloc.city_name
# 什麼是晚上的飛行之後早上8點從東京到東京,flight,3.0,6.0,晚上的,flight_mod,8.0,10.0,之後,depart_time.time_relative,-1.0,1.0,四點,depart_time.time,15.0,17.0,東京,fromloc.city_name,15.0,17.0,東京,toloc.city_name
# 這首爾 之後 四點上華信航空和華信航空直飛航班,flight,62.0,66.0,華信航空,airline_name,62.0,66.0,華信航空,airline_name,1.0,3.0,首爾,stoploc.city_name,4.0,6.0,之後,depart_time.time_relative,7.0,9.0,四點,depart_time.time
# 什麼是東京到東京的最低價的 來回飛行,flight,37.0,41.0,最低價的,cost_relative,42.0,44.0,來回,round_trip,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 讓我從東京所有最低價的票價東京留下星期六,airfare,22.0,26.0,最低價的,cost_relative,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name,17.0,20.0,星期六,depart_date.day_name
# 什麼是東京的最低價的票價東京任何類,airfare,21.0,25.0,最低價的,cost_relative,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 給我的華信航空航班晚上的從今早到東京 東京,flight,17.0,20.0,晚上的,flight_mod,21.0,23.0,今早,depart_date.today_relative,3.0,7.0,華信航空,airline_name,16.0,18.0,東京,fromloc.city_name,16.0,18.0,東京,toloc.city_name
# 我想從東京 JP前往東京上六月 十三點,flight,3.0,5.0,東京,fromloc.city_name,6.0,8.0,JP,fromloc.state_code,3.0,5.0,東京,toloc.city_name,13.0,15.0,六月,depart_date.month_name,16.0,19.0,十三點,depart_date.day_number
# 找到東京和東京之間的轉機飛行留在傍晚的和到達之後下午5點,flight,38.0,40.0,轉機,flight_stop,2.0,4.0,東京,fromloc.city_name,2.0,4.0,東京,toloc.city_name,16.0,19.0,傍晚的,arrive_time.period_of_day,22.0,24.0,之後,arrive_time.time_relative,-1.0,4.0,11:00,arrive_time.time
# 從東京到東京 星期六 早上的何去何從航班,flight,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name,7.0,10.0,星期六,depart_date.day_name,11.0,14.0,早上的,depart_time.period_of_day
# 列出東京從東京上八月 十八號到達的航班,flight,2.0,4.0,東京,toloc.city_name,2.0,4.0,東京,fromloc.city_name,8.0,10.0,八月,arrive_date.month_name,11.0,14.0,十八號,arrive_date.day_number
# 從列出來東京 東京 紅眼 星期六所有航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,12.0,紅眼,depart_time.period_mod,13.0,16.0,星期六,depart_date.day_name
# 請給我所有的東京 韓國到東京 航班,flight,6.0,8.0,東京,fromloc.city_name,9.0,11.0,韓國,fromloc.state_name,6.0,8.0,東京,toloc.city_name,0.0,0.0,,toloc.state_name
# 你有沒有從東京到東京航班上六月 十三點,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,13.0,15.0,六月,depart_date.month_name,16.0,19.0,十三點,depart_date.day_number
# 你能告訴我從東京到東京隨著經濟的票價航班,flight,6.0,8.0,東京,fromloc.city_name,6.0,8.0,東京,toloc.city_name,0.0,0.0,,economy
# 什麼航班從東京對星期六 東京,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,8.0,11.0,星期六,depart_date.day_name
# 是什麼從東京到東京航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 告訴我從東京到東京到達的之後上午10時的所有航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,12.0,14.0,之後,arrive_time.time_relative,-1.0,4.0,11:00,arrive_time.time
# 請給我從東京到東京上星期六 早上的和星期六 早上的航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,13.0,星期六,depart_date.day_name,14.0,17.0,早上的,depart_time.period_of_day,10.0,13.0,星期六,depart_date.day_name,14.0,17.0,早上的,depart_time.period_of_day
# 列出所有航班離開東京 星期六 早上的在東京抵達,flight,8.0,10.0,東京,fromloc.city_name,11.0,14.0,星期六,depart_date.day_name,15.0,18.0,早上的,depart_time.period_of_day,8.0,10.0,東京,toloc.city_name
# 什麼是晚上的 早上的航班離開東京 東京,flight,3.0,6.0,晚上的,flight_mod,7.0,10.0,早上的,depart_time.period_of_day,30.0,32.0,東京,fromloc.city_name,14.0,16.0,東京,toloc.city_name
# 請列出所有航班星期六 東京 東京,flight,7.0,10.0,星期六,depart_date.day_name,11.0,13.0,東京,fromloc.city_name,11.0,13.0,東京,fromloc.city_name
# 從列出來東京 東京 之後 四點上星期六所有航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,12.0,之後,depart_time.time_relative,13.0,15.0,四點,depart_time.time,16.0,19.0,星期六,depart_date.day_name
# 告訴我從東京到東京 轉機所有航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,12.0,轉機,flight_stop
# 我需要從一個東京飛行東京離開星期六 早上的,flight,6.0,8.0,東京,fromloc.city_name,6.0,8.0,東京,toloc.city_name,14.0,17.0,星期六,depart_date.day_name,18.0,21.0,早上的,depart_time.period_of_day
# 我想訂一張從東京航班的東京上六月 十三點,flight,6.0,8.0,東京,fromloc.city_name,6.0,8.0,東京,toloc.city_name,14.0,16.0,六月,depart_date.month_name,17.0,20.0,十三點,depart_date.day_number
# 告訴我的華信航空 東京在早上的航班,flight,4.0,8.0,華信航空,airline_name,9.0,11.0,東京,toloc.city_name,12.0,15.0,早上的,depart_time.period_of_day
# 什麼才是從東京的晚上的飛行東京,flight,23.0,26.0,晚上的,flight_mod,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name
# 我要飛東京到東京上六月 十三點,flight,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name,9.0,11.0,六月,depart_date.month_name,12.0,15.0,十三點,depart_date.day_number
# 我想從東京前往東京,flight,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 什麼航班從東京去東京 之後下午2點,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,11.0,13.0,之後,depart_time.time_relative,-1.0,1.0,四點,depart_time.time
# 我想看到東京到東京所有航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 從東京 JP到東京所有航班六月 十三點,flight,1.0,3.0,東京,fromloc.city_name,4.0,6.0,JP,fromloc.state_code,1.0,3.0,東京,toloc.city_name,13.0,15.0,六月,depart_date.month_name,16.0,19.0,十三點,depart_date.day_number
# 告訴我從東京到東京的早上的航班,flight,38.0,41.0,早上的,depart_time.period_of_day,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 需要多少費用從東京飛轉機到東京上華信航空,airfare,25.0,27.0,轉機,flight_stop,7.0,9.0,東京,fromloc.city_name,7.0,9.0,東京,toloc.city_name,16.0,20.0,華信航空,airline_name
# 給我從東京到東京 航班的六月 十三點,flight,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name,0.0,0.0,,toloc.state_code,12.0,14.0,六月,depart_date.month_name,15.0,18.0,十三點,depart_date.day_number
# 我想對航班將東京和東京到達信息,flight,6.0,8.0,東京,fromloc.city_name,6.0,8.0,東京,toloc.city_name
# 請告訴我從東京 JP到東京 航班,flight,5.0,7.0,東京,fromloc.city_name,8.0,10.0,JP,fromloc.state_code,5.0,7.0,東京,toloc.city_name,0.0,0.0,,toloc.state_name
# 什麼航班從東京到東京,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name
# 從東京和東京到東京航班抵達在同一時間,flight,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name
# 告訴我從東京到東京上星期六 早上的或星期六 早上的航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,13.0,星期六,depart_date.day_name,14.0,17.0,早上的,depart_time.period_of_day,17.0,18.0,或,or,10.0,13.0,星期六,depart_date.day_name,14.0,17.0,早上的,depart_time.period_of_day
# 從列出來東京 東京 的轉機航班,flight,55.0,57.0,轉機,flight_stop,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,0.0,0.0,,toloc.state_code
# 你可以列出所有航班從東京和著陸的前提下，東京與首爾短暫停留,flight,10.0,12.0,東京,fromloc.city_name,10.0,12.0,東京,toloc.city_name,23.0,25.0,首爾,stoploc.city_name
# 給我星期六航班從東京到東京,flight,2.0,5.0,星期六,depart_date.day_name,8.0,10.0,東京,fromloc.city_name,8.0,10.0,東京,toloc.city_name
# 你可以給我東京和東京之間的航班,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name
# 我想看到東京到東京的每天航班,flight,38.0,40.0,每天,flight_days,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 在首爾中途停留的所有華信航空和華信航空航班,flight,25.0,29.0,華信航空,airline_name,25.0,29.0,華信航空,airline_name,1.0,3.0,首爾,stoploc.city_name
# 從東京列表轉機航班東京是出發的傍晚的,flight,20.0,22.0,轉機,flight_stop,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name,15.0,18.0,傍晚的,arrive_time.period_of_day
# 從東京到東京航班,flight,1.0,3.0,東京,fromloc.city_name,1.0,3.0,東京,toloc.city_name
# 給我所有從東京航班上華信航空 東京,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,10.0,14.0,華信航空,airline_name
# 有沒有在一個華信航空航班從東京要東京上六月 十三點,flight,6.0,10.0,華信航空,airline_name,13.0,15.0,東京,fromloc.city_name,13.0,15.0,東京,toloc.city_name,19.0,21.0,六月,depart_date.month_name,22.0,25.0,十三點,depart_date.day_number
# 我要飛從東京到東京,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 早上的 東京和東京之間早上的航班,flight,0.0,3.0,早上的,depart_time.period_of_day,0.0,3.0,早上的,depart_time.period_of_day,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 在六月 十三點我想從東京預訂航班到東京,flight,1.0,3.0,六月,depart_date.month_name,4.0,7.0,十三點,depart_date.day_number,10.0,12.0,東京,fromloc.city_name,10.0,12.0,東京,toloc.city_name
# 什麼早上的航班東京和東京之間可用,flight,2.0,5.0,早上的,depart_time.period_of_day,7.0,9.0,東京,fromloc.city_name,7.0,9.0,東京,toloc.city_name
# 什麼是東京到東京的晚上的飛行,flight,37.0,40.0,晚上的,flight_mod,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 從列出來東京 東京 之後 四點上星期六所有航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,12.0,之後,depart_time.time_relative,13.0,15.0,四點,depart_time.time,16.0,19.0,星期六,depart_date.day_name
# 什麼是晚上的航班從東京離開去東京,flight,3.0,6.0,晚上的,flight_mod,9.0,11.0,東京,fromloc.city_name,9.0,11.0,東京,toloc.city_name
# 我需要從東京飛往東京這個星期六,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,12.0,15.0,星期六,depart_date.day_name
# 什麼航班從東京離開東京在早上的,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,12.0,15.0,早上的,depart_time.period_of_day
# 什麼轉機 東京和東京之間的航班??抵達之後 11:00,flight,2.0,4.0,轉機,flight_stop,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,19.0,21.0,之後,arrive_time.time_relative,22.0,27.0,11:00,arrive_time.time
# 什麼才是從東京到東京的華信航空次航班票價,airfare,39.0,43.0,華信航空,airline_name,-1.0,5.0,CI0150,flight_number,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name
# 什麼航班從東京去東京 之後下午5點,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,11.0,13.0,之後,depart_time.time_relative,-1.0,1.0,四點,depart_time.time
# 哪些航班從有到東京 東京,flight,7.0,9.0,東京,fromloc.city_name,7.0,9.0,東京,toloc.city_name
# 你有沒有從東京到東京  下(next) 星期六飛行,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,0.0,0.0,,toloc.state_name,12.0,19.0,下(next),depart_date.date_relative,20.0,23.0,星期六,depart_date.day_name
# 什麼航班從東京去上星期六 東京 ,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,0.0,0.0,,toloc.state_code,9.0,12.0,星期六,depart_date.day_name
# 請安排從東京對我來說是飛行到華信航空 東京,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,14.0,18.0,華信航空,airline_name
# 告訴我從東京到東京上星期六航班,flight,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name,10.0,13.0,星期六,depart_date.day_name
# 什麼是東京和東京之間的最低價的機票,airfare,39.0,43.0,最低價的,cost_relative,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 需要從東京到東京飛行,flight,3.0,5.0,東京,fromloc.city_name,3.0,5.0,東京,toloc.city_name
# 告訴我從東京到東京的晚上的飛行,flight,38.0,41.0,晚上的,flight_mod,4.0,6.0,東京,fromloc.city_name,4.0,6.0,東京,toloc.city_name
# 你有沒有從東京到東京上下(next)週星期六在早上的任何航班,flight,5.0,7.0,東京,fromloc.city_name,5.0,7.0,東京,toloc.city_name,37.0,40.0,星期六,depart_date.day_name,11.0,18.0,下(next),depart_date.date_relative,23.0,26.0,早上的,depart_time.period_of_day
# 從fromloc.city_name到toloc.city_name，在arrive_time.time arrive_date.date_relative arrive_date.day_name到達所有航班,flight,17.0,27.0,pittsburgh,fromloc.city_name,31.0,43.0,philadelphia,toloc.city_name,59.0,68.0,6 o'clock,arrive_time.time,69.0,73.0,next,arrive_date.date_relative,74.0,81.0,tuesday,arrive_date.day_name
# 請列出從fromloc.city_name到toloc.city_name航班,flight,29.0,40.0,kansas city,fromloc.city_name,44.0,50.0,denver,toloc.city_name
# 給我depart_date.month_name depart_date.day_number的航班和票價從fromloc.city_name到toloc.city_name,flight+airfare,33.0,41.0,december,depart_date.month_name,42.0,56.0,twenty seventh,depart_date.day_number,62.0,74.0,indianapolis,fromloc.city_name,78.0,85.0,orlando,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,31.0,boston,fromloc.city_name,35.0,44.0,baltimore,toloc.city_name
# 我需要flight_mod飛行depart_date.day_name從fromloc.city_name到toloc.city_name,flight,7.0,11.0,late,flight_mod,19.0,28.0,wednesday,depart_date.day_name,34.0,41.0,oakland,fromloc.city_name,45.0,59.0,salt lake city,toloc.city_name
# 請告訴我從fromloc.city_name到toloc.city_name所有round_trip航班,flight,19.0,29.0,round trip,round_trip,43.0,51.0,new york,fromloc.city_name,55.0,60.0,miami,toloc.city_name
# 什麼航空公司有從fromloc.city_name到toloc.city_name flight_stop depart_time.period_of_day arrive_time.period_of_day航班,airline,19.0,26.0,nonstop,flight_stop,27.0,32.0,early,depart_time.period_of_day,33.0,42.0,afternoon,arrive_time.period_of_day,56.0,62.0,boston,fromloc.city_name,66.0,72.0,denver,toloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行,flight,12.0,16.0,last,flight_mod,29.0,35.0,boston,fromloc.city_name,39.0,46.0,atlanta,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name航班airline_name為depart_date.month_name depart_date.day_number名單,flight,31.0,37.0,denver,fromloc.city_name,41.0,50.0,baltimore,toloc.city_name,54.0,60.0,united,airline_name,65.0,71.0,august,depart_date.month_name,72.0,77.0,third,depart_date.day_number
# 什麼航班從airline_name在toloc.city_name到達,flight,23.0,30.0,seattle,toloc.city_name,39.0,50.0,continental,airline_name
# 給我從fromloc.city_name航班上depart_date.day_name toloc.city_name,flight,25.0,32.0,phoenix,fromloc.city_name,36.0,45.0,milwaukee,toloc.city_name,49.0,58.0,wednesday,depart_date.day_name
# 我想一個航班從fromloc.city_name上depart_date.month_name depart_date.day_number留給toloc.city_name在depart_time.time,flight,35.0,45.0,washington,fromloc.city_name,49.0,55.0,boston,toloc.city_name,59.0,65.0,110 pm,depart_time.time,69.0,75.0,august,depart_date.month_name,76.0,85.0,twentieth,depart_date.day_number
# 該航空公司從fromloc.city_name到toloc.city_name飛,airline,24.0,30.0,boston,fromloc.city_name,34.0,44.0,washington,toloc.city_name
# 給我留下fromloc.city_name到toloc.city_name depart_time.time_relative 7時許depart_date.date_relative depart_date.day_name航班,flight,28.0,37.0,charlotte,fromloc.city_name,41.0,48.0,atlanta,toloc.city_name,49.0,55.0,around,depart_time.time_relative,56.0,60.0,07:00 PM,depart_time.time,61.0,65.0,next,depart_date.date_relative,66.0,73.0,tuesday,depart_date.day_name
# 告訴我round_trip fromloc.city_name和toloc.city_name toloc.state_code之間的票價,airfare,8.0,18.0,round trip,round_trip,33.0,46.0,san francisco,fromloc.city_name,51.0,61.0,washington,toloc.city_name,62.0,64.0,dc,toloc.state_code
# 請你告訴我，從fromloc.city_name到toloc.city_name所有航班,flight,42.0,51.0,milwaukee,fromloc.city_name,55.0,63.0,montreal,toloc.city_name
# 是什麼從fromloc.city_name到toloc.city_name航班上depart_date.day_name的depart_date.day_number,flight,26.0,34.0,san jose,fromloc.city_name,38.0,47.0,nashville,toloc.city_name,51.0,59.0,thursday,depart_date.day_name,64.0,73.0,twentieth,depart_date.day_number
# 什麼是fromloc.city_name的cost_relative票價toloc.city_name留下depart_date.month_name depart_date.day_number,airfare,12.0,27.0,least expensive,cost_relative,38.0,47.0,baltimore,fromloc.city_name,51.0,64.0,san francisco,toloc.city_name,76.0,85.0,september,depart_date.month_name,86.0,95.0,thirtieth,depart_date.day_number
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,21.0,34.0,san francisco,fromloc.city_name,38.0,45.0,atlanta,toloc.city_name
# 從fromloc.city_name到toloc.city_name fromloc.city_name航班depart_date.day_name航班,flight,13.0,19.0,boston,fromloc.city_name,33.0,45.0,philadelphia,fromloc.city_name,49.0,55.0,boston,toloc.city_name,59.0,65.0,monday,depart_date.day_name
# 告訴我從fromloc.city_name到toloc.city_name其離開fromloc.city_name depart_time.time_relative depart_time.time depart_date.today_relative所有航班,flight,25.0,31.0,boston,fromloc.city_name,35.0,42.0,atlanta,toloc.city_name,55.0,62.0,atlanta,fromloc.city_name,63.0,68.0,after,depart_time.time_relative,69.0,73.0,noon,depart_time.time,74.0,82.0,tomorrow,depart_date.today_relative
# 什麼航班從fromloc.city_name對depart_date.day_name toloc.city_name,flight,18.0,24.0,dallas,fromloc.city_name,28.0,35.0,houston,toloc.city_name,39.0,45.0,sunday,depart_date.day_name
# 是什麼的所有航班從fromloc.city_name對depart_date.day_name toloc.city_name,flight,26.0,32.0,boston,fromloc.city_name,36.0,46.0,pittsburgh,toloc.city_name,50.0,60.0,wednesdays,depart_date.day_name
# 給我從fromloc.city_name飛行對depart_date.day_name toloc.city_name,flight,22.0,27.0,tampa,fromloc.city_name,31.0,40.0,charlotte,toloc.city_name,44.0,50.0,sunday,depart_date.day_name
# 告訴我cost_relative round_trip票價從fromloc.city_name到toloc.city_name,airfare,12.0,20.0,cheapest,cost_relative,21.0,31.0,round trip,round_trip,43.0,56.0,san francisco,fromloc.city_name,60.0,74.0,salt lake city,toloc.city_name
# 什麼航班從fromloc.city_name到toloc.city_name去,flight,21.0,27.0,dallas,fromloc.city_name,31.0,40.0,baltimore,toloc.city_name
# 讓我從fromloc.city_name所有航班airline_name,flight,12.0,29.0,canadian airlines,airline_name,43.0,50.0,toronto,fromloc.city_name
# 從fromloc.city_name到toloc.city_name航班depart_date.day_name depart_time.period_of_day,flight,13.0,20.0,phoenix,fromloc.city_name,24.0,33.0,milwaukee,toloc.city_name,37.0,46.0,wednesday,depart_date.day_name,47.0,54.0,evening,depart_time.period_of_day
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,30.0,miami,fromloc.city_name,34.0,40.0,denver,toloc.city_name
# 請找到fromloc.city_name到toloc.city_name的cost_relative票價,airfare,16.0,24.0,cheapest,cost_relative,35.0,41.0,boston,fromloc.city_name,45.0,58.0,san francisco,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name航班,flight,21.0,27.0,boston,fromloc.city_name,31.0,37.0,denver,toloc.city_name,41.0,48.0,tuesday,depart_date.day_name
# 顯示航班和票價信息，從fromloc.city_name通過stoploc.city_name到toloc.city_name連接,flight,39.0,49.0,pittsburgh,fromloc.city_name,50.0,60.0,connecting,connect,69.0,75.0,denver,stoploc.city_name,79.0,86.0,oakland,toloc.city_name
# 列出所有留下depart_date.day_name depart_time.period_of_day從fromloc.city_name到toloc.city_name航班,flight,28.0,36.0,thursday,depart_date.day_name,37.0,44.0,morning,depart_time.period_of_day,50.0,63.0,new york city,fromloc.city_name,67.0,75.0,montreal,toloc.city_name
# 我需要從fromloc.city_name到toloc.city_name飛行,flight,21.0,27.0,boston,fromloc.city_name,31.0,41.0,pittsburgh,toloc.city_name
# 從列出來fromloc.city_name toloc.city_name flight_stop上depart_date.day_name所有航班,flight,20.0,26.0,sunday,depart_date.day_name,32.0,45.0,san francisco,fromloc.city_name,49.0,59.0,pittsburgh,toloc.city_name,60.0,67.0,nonstop,flight_stop
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name depart_date.date_relative depart_date.day_name其離開depart_time.time_relative depart_time.time所有航班,flight,25.0,31.0,denver,fromloc.city_name,35.0,47.0,philadelphia,toloc.city_name,51.0,59.0,saturday,depart_date.day_name,60.0,65.0,after,depart_date.date_relative,66.0,72.0,sunday,depart_date.day_name,85.0,90.0,after,depart_time.time_relative,91.0,95.0,noon,depart_time.time
# 請列出從fromloc.city_name到toloc.city_name的airline_name航班depart_date.day_name depart_date.month_name depart_date.day_number,flight,16.0,33.0,american airlines,airline_name,47.0,59.0,philadelphia,fromloc.city_name,63.0,69.0,dallas,toloc.city_name,73.0,80.0,tuesday,depart_date.day_name,81.0,88.0,october,depart_date.month_name,89.0,94.0,first,depart_date.day_number
# 給我從fromloc.city_name到toloc.city_name的航班depart_date.month_name depart_date.day_number和depart_date.day_number,flight,25.0,37.0,indianapolis,fromloc.city_name,41.0,48.0,orlando,toloc.city_name,52.0,60.0,december,depart_date.month_name,61.0,75.0,twenty seventh,depart_date.day_number,80.0,93.0,twenty eighth,depart_date.day_number
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,32.0,oakland,fromloc.city_name,36.0,42.0,denver,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name離開fromloc.city_name depart_time.start_time至下午7時之間的航班,flight,27.0,34.0,toronto,fromloc.city_name,38.0,52.0,salt lake city,toloc.city_name,61.0,68.0,toronto,fromloc.city_name,77.0,80.0,530,depart_time.start_time,85.0,89.0,07:00 PM,depart_time.end_time
# 告訴我從fromloc.city_name到toloc.city_name到達的arrive_time.time_relative晚上7點的所有航班,flight,25.0,36.0,minneapolis,fromloc.city_name,40.0,49.0,san diego,toloc.city_name,62.0,68.0,before,arrive_time.time_relative,69.0,73.0,07:00 PM,arrive_time.time
# 我需要從fromloc.city_name到toloc.city_name飛行,flight,21.0,33.0,philadelphia,fromloc.city_name,37.0,43.0,dallas,toloc.city_name
# fromloc.city_name到toloc.city_name depart_date.day_name,flight,1.0,13.0,philadelphia,fromloc.city_name,16.0,22.0,boston,toloc.city_name,23.0,31.0,saturday,depart_date.day_name
# 該航空公司從fromloc.city_name飛往toloc.city_name並在stoploc.city_name停留,airline,24.0,31.0,toronto,fromloc.city_name,35.0,44.0,san diego,toloc.city_name,68.0,74.0,denver,stoploc.city_name
# 什麼航班從fromloc.city_name去toloc.city_name在depart_time.period_of_day,flight,21.0,30.0,charlotte,fromloc.city_name,34.0,43.0,baltimore,toloc.city_name,51.0,58.0,morning,depart_time.period_of_day
# 什麼航班離開fromloc.city_name fromloc.state_code並在arrive_date.day_name toloc.city_name到達,flight,19.0,29.0,washington,fromloc.city_name,30.0,32.0,dc,fromloc.state_code,47.0,60.0,san francisco,toloc.city_name,64.0,73.0,wednesday,arrive_date.day_name
# 什麼是fromloc.city_name和toloc.city_name之間的cost_relative票價,airfare,13.0,28.0,least expensive,cost_relative,42.0,49.0,atlanta,fromloc.city_name,54.0,60.0,boston,toloc.city_name
# 什麼是flight_mod飛離fromloc.city_name為toloc.city_name depart_date.day_name,flight,12.0,18.0,latest,flight_mod,34.0,40.0,newark,fromloc.city_name,45.0,56.0,los angeles,toloc.city_name,57.0,66.0,wednesday,depart_date.day_name
# 告訴我從fromloc.city_name到toloc.city_name toloc.state_code上depart_date.day_name depart_time.period_of_day航班,flight,25.0,32.0,atlanta,fromloc.city_name,36.0,46.0,washington,toloc.city_name,47.0,49.0,dc,toloc.state_code,53.0,61.0,thursday,depart_date.day_name,62.0,69.0,evening,depart_time.period_of_day
# 告訴我從fromloc.city_name到toloc.city_name depart_date.date_relative depart_date.day_name航班,flight,27.0,36.0,charlotte,fromloc.city_name,40.0,47.0,atlanta,toloc.city_name,48.0,52.0,next,depart_date.date_relative,53.0,60.0,tuesday,depart_date.day_name
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,21.0,28.0,atlanta,fromloc.city_name,32.0,42.0,washington,toloc.city_name
# 請給我depart_time.period_of_day航班離開fromloc.city_name到toloc.city_name depart_date.day_name,flight,15.0,22.0,evening,depart_time.period_of_day,39.0,51.0,philadelphia,fromloc.city_name,55.0,68.0,san francisco,toloc.city_name,69.0,75.0,friday,depart_date.day_name
# 什麼才是從fromloc.city_name到toloc.city_name的cost_relative round_trip票價,airfare,12.0,18.0,lowest,cost_relative,19.0,29.0,round trip,round_trip,40.0,47.0,atlanta,fromloc.city_name,51.0,61.0,pittsburgh,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name離開depart_time.time_relative depart_time.time和到達arrive_time.time_relative晚上7點航班列表,flight,31.0,37.0,boston,fromloc.city_name,41.0,48.0,atlanta,toloc.city_name,57.0,62.0,after,depart_time.time_relative,63.0,67.0,noon,depart_time.time,81.0,87.0,before,arrive_time.time_relative,88.0,92.0,07:00 PM,arrive_time.time
# 哪些航班從有到fromloc.city_name toloc.city_name,flight,28.0,34.0,denver,fromloc.city_name,38.0,45.0,atlanta,toloc.city_name
# 給我上depart_date.day_name depart_time.period_of_day fromloc.city_name到toloc.city_name的airline_name class_type航班,flight,19.0,28.0,wednesday,depart_date.day_name,29.0,36.0,morning,depart_time.period_of_day,37.0,43.0,boston,fromloc.city_name,47.0,53.0,denver,toloc.city_name,58.0,73.0,united airlines,airline_name,74.0,85.0,first class,class_type
# 我想從fromloc.city_name到toloc.city_name計劃airline_name航班,flight,33.0,50.0,american airlines,airline_name,56.0,62.0,boston,fromloc.city_name,66.0,72.0,denver,toloc.city_name
# 清單depart_time.period_of_day航班從fromloc.city_name到toloc.city_name depart_date.today_relative,flight,5.0,12.0,evening,depart_time.period_of_day,21.0,29.0,tomorrow,depart_date.today_relative,35.0,42.0,phoenix,fromloc.city_name,46.0,53.0,detroit,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name所有航班depart_date.day_name depart_time.time_relative depart_time.time,flight,25.0,31.0,boston,fromloc.city_name,35.0,45.0,pittsburgh,toloc.city_name,49.0,58.0,wednesday,depart_date.day_name,59.0,64.0,after,depart_time.time_relative,65.0,77.0,6 o'clock pm,depart_time.time
# 我想要看到fromloc.city_name到toloc.city_name所有航班,flight,34.0,40.0,denver,fromloc.city_name,44.0,56.0,philadelphia,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,34.0,baltimore,fromloc.city_name,38.0,50.0,philadelphia,toloc.city_name
# 請給我從fromloc.city_name航班的toloc.city_name depart_time.time_relative上午10時在depart_time.period_of_day,flight,29.0,35.0,boston,fromloc.city_name,39.0,46.0,atlanta,toloc.city_name,47.0,53.0,before,depart_time.time_relative,54.0,59.0,10:00 AM,depart_time.time,67.0,74.0,morning,depart_time.period_of_day
# 您好我能得到一個round_trip票從fromloc.city_name到toloc.city_name,airfare,17.0,24.0,one way,round_trip,37.0,46.0,milwaukee,fromloc.city_name,50.0,57.0,orlando,toloc.city_name
# 我希望看到fromloc.city_name到toloc.city_name的cost_relative飛行,flight,18.0,26.0,cheapest,cost_relative,39.0,45.0,denver,fromloc.city_name,49.0,59.0,pittsburgh,toloc.city_name
# 從展示到fromloc.city_name toloc.city_name depart_time.period_of_day航班,flight,5.0,14.0,afternoon,depart_time.period_of_day,28.0,34.0,dallas,fromloc.city_name,38.0,51.0,san francisco,toloc.city_name
# 什麼航班離開depart_time.time_relative 7日下午從fromloc.city_name到toloc.city_name,flight,19.0,24.0,after,depart_time.time_relative,25.0,29.0,07:00 PM,depart_time.time,35.0,41.0,boston,fromloc.city_name,45.0,55.0,pittsburgh,toloc.city_name
# 從fromloc.city_name到toloc.city_name航班,flight,13.0,20.0,phoenix,fromloc.city_name,24.0,30.0,newark,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name到toloc.city_name航班和回程航班從fromloc.city_name,flight,25.0,31.0,boston,fromloc.city_name,35.0,42.0,atlanta,toloc.city_name,71.0,78.0,atlanta,fromloc.city_name,82.0,88.0,boston,toloc.city_name
# 多少flight_stop航班從去到fromloc.city_name toloc.city_name arrive_date.month_name arrive_date.day_number,quantity,9.0,16.0,nonstop,flight_stop,36.0,42.0,dallas,fromloc.city_name,46.0,53.0,oakland,toloc.city_name,54.0,58.0,july,arrive_date.month_name,59.0,73.0,twenty seventh,arrive_date.day_number
# 請列出從fromloc.city_name到toloc.city_name上depart_date.day_name depart_time.period_of_day所有航班,flight,29.0,36.0,oakland,fromloc.city_name,40.0,46.0,dallas,toloc.city_name,50.0,56.0,sunday,depart_date.day_name,57.0,64.0,morning,depart_time.period_of_day
# 在列出airline_name離開fromloc.city_name所有航班depart_date.day_name depart_time.time_relative depart_time.time,flight,20.0,31.0,continental,airline_name,40.0,47.0,seattle,fromloc.city_name,51.0,57.0,sunday,depart_date.day_name,58.0,63.0,after,depart_time.time_relative,64.0,70.0,430 pm,depart_time.time
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行,flight,12.0,18.0,latest,flight_mod,31.0,44.0,san francisco,fromloc.city_name,48.0,58.0,washington,toloc.city_name
# 什麼航班離開airline_name fromloc.city_name depart_time.time_relative depart_time.time,flight,19.0,25.0,denver,fromloc.city_name,26.0,32.0,before,depart_time.time_relative,33.0,37.0,noon,depart_time.time,41.0,59.0,northwest airlines,airline_name
# 什麼航班離開fromloc.city_name depart_date.month_name depart_date.day_number depart_time.time_relative 7日下午在抵達toloc.city_name,flight,19.0,29.0,pittsburgh,fromloc.city_name,30.0,34.0,july,depart_date.month_name,35.0,40.0,fifth,depart_date.day_number,41.0,46.0,after,depart_time.time_relative,47.0,51.0,07:00 PM,depart_time.time,66.0,79.0,san francisco,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,34.0,baltimore,fromloc.city_name,38.0,50.0,philadelphia,toloc.city_name
# 告訴我在depart_time.period_of_day從fromloc.city_name到toloc.city_name航班,flight,21.0,28.0,atlanta,fromloc.city_name,32.0,44.0,philadelphia,toloc.city_name,52.0,59.0,morning,depart_time.period_of_day
# 我想從fromloc.city_name飛往toloc.city_name在stoploc.city_name短暫停留,flight,25.0,32.0,atlanta,fromloc.city_name,36.0,49.0,san francisco,toloc.city_name,69.0,75.0,dallas,stoploc.city_name
# 我想飛到toloc.city_name,flight,23.0,32.0,baltimore,toloc.city_name
# 我想從fromloc.city_name到toloc.city_name航班上在depart_time.time depart_date.month_name depart_date.day_number,flight,27.0,37.0,washington,fromloc.city_name,41.0,47.0,boston,toloc.city_name,51.0,57.0,august,depart_date.month_name,58.0,67.0,twentieth,depart_date.day_number,71.0,77.0,324 pm,depart_time.time
# fromloc.city_name和toloc.city_name toloc.state_name之間depart_date.day_name depart_time.period_of_day航班,flight,1.0,10.0,wednesday,depart_date.day_name,10.0,17.0,morning,depart_time.period_of_day,34.0,43.0,baltimore,fromloc.city_name,48.0,54.0,newark,toloc.city_name,55.0,65.0,new jersey,toloc.state_name
# 像從fromloc.city_name航班的toloc.city_name在depart_time.period_of_day depart_date.month_name depart_date.day_number 我,flight,3.0,7.0,july,depart_date.month_name,8.0,14.0,eighth,depart_date.day_number,39.0,45.0,newark,fromloc.city_name,49.0,56.0,orlando,toloc.city_name,64.0,71.0,morning,depart_time.period_of_day
# 是什麼從fromloc.city_name到toloc.city_name航班,flight,26.0,32.0,denver,fromloc.city_name,36.0,43.0,oakland,toloc.city_name
# 什麼航班從fromloc.city_name去toloc.city_name depart_time.time_relative depart_time.time在depart_time.period_of_day,flight,21.0,31.0,pittsburgh,fromloc.city_name,35.0,41.0,newark,toloc.city_name,42.0,47.0,after,depart_time.time_relative,48.0,51.0,823,depart_time.time,59.0,66.0,morning,depart_time.period_of_day
# 告訴我從fromloc.city_name到toloc.airport_code航班,flight,25.0,32.0,atlanta,fromloc.city_name,36.0,39.0,bwi,toloc.airport_code
# 是什麼fromloc.city_name和toloc.city_name之間的航班,flight,29.0,39.0,pittsburgh,fromloc.city_name,44.0,57.0,san francisco,toloc.city_name
# 告訴我航班從fromloc.city_name class_type到toloc.city_name在depart_time.period_of_day和depart_time.time_relative depart_time.time留下depart_date.day_name depart_time.time_relative depart_time.time,flight,16.0,27.0,first class,class_type,33.0,46.0,san francisco,fromloc.city_name,50.0,60.0,pittsburgh,toloc.city_name,72.0,79.0,tuesday,depart_date.day_name,80.0,85.0,after,depart_time.time_relative,86.0,95.0,8 o'clock,depart_time.time,103.0,110.0,morning,depart_time.period_of_day,115.0,121.0,before,depart_time.time_relative,122.0,129.0,12 noon,depart_time.time
# 從fromloc.city_name到toloc.city_name航班arrive_time.start_time下午5點抵達,flight,13.0,23.0,pittsburgh,fromloc.city_name,27.0,36.0,baltimore,toloc.city_name,54.0,55.0,4,arrive_time.start_time,60.0,64.0,05:00 PM,arrive_time.end_time
# 什麼是cost_relative車費，我可以fromloc.city_name和toloc.city_name之間得到,airfare,12.0,20.0,cheapest,cost_relative,49.0,61.0,philadelphia,fromloc.city_name,66.0,79.0,san francisco,toloc.city_name
# 什麼飛行你從fromloc.city_name必須toloc.city_name上的depart_time.period_of_day depart_date.month_name depart_date.day_number,flight,29.0,35.0,dallas,fromloc.city_name,39.0,45.0,denver,toloc.city_name,49.0,55.0,august,depart_date.month_name,56.0,70.0,twenty seventh,depart_date.day_number,78.0,85.0,morning,depart_time.period_of_day
# 我需要從fromloc.city_name到toloc.city_name飛行,flight,21.0,34.0,san francisco,fromloc.city_name,38.0,50.0,philadelphia,toloc.city_name
# 我想從一個fromloc.city_name飛行flight_stop到toloc.city_name葉色arrive_date.day_name arrive_time.period_of_day,flight,9.0,16.0,nonstop,flight_stop,29.0,41.0,indianapolis,fromloc.city_name,45.0,52.0,toronto,toloc.city_name,65.0,73.0,thursday,arrive_date.day_name,74.0,81.0,morning,arrive_time.period_of_day
# 給我所有從fromloc.city_name到toloc.city_name round_trip航班,flight,29.0,37.0,new york,fromloc.city_name,41.0,46.0,miami,toloc.city_name,47.0,57.0,round trip,round_trip
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.month_name depart_date.day_number可用航班,flight,35.0,48.0,san francisco,fromloc.city_name,52.0,58.0,boston,toloc.city_name,62.0,70.0,november,depart_date.month_name,71.0,84.0,twenty fourth,depart_date.day_number
# 什麼是fromloc.city_name到toloc.city_name class_type round_trip票價,airfare,22.0,34.0,philadelphia,fromloc.city_name,38.0,48.0,pittsburgh,toloc.city_name,49.0,63.0,business class,class_type,64.0,71.0,one way,round_trip
# 什麼是在當天flight_mod航班從fromloc.city_name到toloc.city_name,flight,12.0,18.0,latest,flight_mod,42.0,51.0,baltimore,fromloc.city_name,55.0,62.0,atlanta,toloc.city_name
# 給我上depart_date.month_name depart_date.day_number航班，請,flight,19.0,28.0,september,depart_date.month_name,29.0,41.0,twenty sixth,depart_date.day_number
# 什麼是fromloc.city_name的flight_mod飛行toloc.city_name這個depart_date.day_name,flight,12.0,16.0,last,flight_mod,29.0,42.0,san francisco,fromloc.city_name,46.0,52.0,boston,toloc.city_name,58.0,67.0,wednesday,depart_date.day_name
# 請告訴我depart_time.period_of_day depart_time.period_of_day從fromloc.city_name到toloc.city_name上depart_date.day_name,flight,15.0,20.0,early,depart_time.period_of_day,21.0,28.0,morning,depart_time.period_of_day,42.0,49.0,atlanta,fromloc.city_name,53.0,65.0,philadelphia,toloc.city_name,69.0,78.0,wednesday,depart_date.day_name
# 告訴我fromloc.city_name和toloc.city_name之間的airline_name所有連接航班,flight,12.0,22.0,connecting,connect,34.0,49.0,united airlines,airline_name,58.0,64.0,boston,fromloc.city_name,69.0,82.0,san francisco,toloc.city_name
# 您好我'd像從fromloc.city_name到toloc.city_name airline_name飛行請,flight,25.0,40.0,alaska airlines,airline_name,46.0,55.0,san diego,fromloc.city_name,59.0,66.0,toronto,toloc.city_name
# 請告訴我航班從fromloc.city_name到toloc.city_name停止stoploc.city_name航班,airline,42.0,48.0,denver,fromloc.city_name,52.0,58.0,boston,toloc.city_name,64.0,76.0,philadelphia,stoploc.city_name
# 列出airline_name航班是離開fromloc.city_name depart_time.time_relative depart_time.time,flight,9.0,27.0,northwest airlines,airline_name,47.0,53.0,denver,fromloc.city_name,54.0,60.0,before,depart_time.time_relative,61.0,65.0,noon,depart_time.time
# 什麼類型的飛機確實從fromloc.city_name到toloc.city_name depart_time.time_relative下午6點airline_name飛,aircraft,27.0,34.0,eastern,airline_name,44.0,51.0,atlanta,fromloc.city_name,55.0,61.0,denver,toloc.city_name,62.0,68.0,before,depart_time.time_relative,69.0,73.0,06:00 PM,depart_time.time
# 我要飛從fromloc.city_name到toloc.city_name,flight,19.0,25.0,boston,fromloc.city_name,29.0,42.0,san francisco,toloc.city_name
# 我想在離開depart_time.period_mod depart_date.day_name depart_time.period_of_day從fromloc.city_name到toloc.city_name航班信息,flight,44.0,49.0,early,depart_time.period_mod,50.0,56.0,monday,depart_date.day_name,57.0,64.0,morning,depart_time.period_of_day,70.0,77.0,atlanta,fromloc.city_name,81.0,90.0,baltimore,toloc.city_name
# 列出所有在toloc.airport_name到達的航班,flight,36.0,74.0,general mitchell international airport,toloc.airport_name
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行,flight,12.0,16.0,last,flight_mod,29.0,42.0,san francisco,fromloc.city_name,46.0,63.0,dallas fort worth,toloc.city_name
# 列出cost_relative航班從fromloc.city_name到toloc.city_name,flight,5.0,20.0,least expensive,cost_relative,33.0,39.0,dallas,fromloc.city_name,43.0,52.0,baltimore,toloc.city_name
# 清單航班從fromloc.city_name到toloc.city_name,flight,18.0,28.0,pittsburgh,fromloc.city_name,32.0,45.0,san francisco,toloc.city_name
# 列出所有留下的airline_name fromloc.city_name上depart_date.day_name depart_time.time_relative depart_time.time航班,flight,25.0,31.0,denver,fromloc.city_name,35.0,46.0,continental,airline_name,50.0,56.0,sunday,depart_date.day_name,57.0,62.0,after,depart_time.time_relative,63.0,69.0,934 pm,depart_time.time
# 你將能夠把我在航班上與airline_name離開depart_date.month_name depart_date.day_number的depart_time.period_of_day從fromloc.city_name到toloc.city_name,flight,45.0,50.0,delta,airline_name,63.0,70.0,morning,depart_time.period_of_day,74.0,80.0,august,depart_date.month_name,81.0,95.0,twenty seventh,depart_date.day_number,101.0,110.0,baltimore,fromloc.city_name,114.0,127.0,san francisco,toloc.city_name
# 什麼航班從fromloc.city_name到toloc.city_name去,flight,21.0,34.0,san francisco,fromloc.city_name,38.0,44.0,dallas,toloc.city_name
# 什麼是從fromloc.city_name到toloc.city_name一個round_trip飛行cost_relative票價,airfare,12.0,20.0,cheapest,cost_relative,32.0,39.0,one way,round_trip,52.0,58.0,boston,fromloc.city_name,62.0,69.0,atlanta,toloc.city_name
# 告訴我什麼是航班可從fromloc.city_name與經濟艙票價toloc.city_name,flight,40.0,49.0,baltimore,fromloc.city_name,53.0,59.0,dallas,toloc.city_name,65.0,72.0,economy,economy
# 什麼是fromloc.city_name的cost_relative票價上airline_name toloc.city_name,airfare,12.0,20.0,cheapest,cost_relative,31.0,37.0,dallas,fromloc.city_name,41.0,47.0,denver,toloc.city_name,51.0,56.0,delta,airline_name
# 請告訴我航班從fromloc.city_name到toloc.city_name航班,airline,42.0,54.0,philadelphia,fromloc.city_name,58.0,64.0,dallas,toloc.city_name
# 從fromloc.city_name到toloc.city_name航班arrive_time.start_time下午5點抵達,flight,13.0,23.0,pittsburgh,fromloc.city_name,27.0,36.0,baltimore,toloc.city_name,54.0,55.0,4,arrive_time.start_time,60.0,64.0,05:00 PM,arrive_time.end_time
# 從定位到fromloc.city_name在toloc.city_name停止stoploc.airport_name航班,flight,20.0,32.0,philadelphia,fromloc.city_name,36.0,42.0,dallas,toloc.city_name,55.0,64.0,hartfield,stoploc.airport_name
# 我試圖找到對depart_date.day_name的depart_date.day_number從fromloc.city_name到toloc.city_name飛行,flight,34.0,45.0,kansas city,fromloc.city_name,49.0,56.0,burbank,toloc.city_name,60.0,68.0,saturday,depart_date.day_name,73.0,86.0,twenty second,depart_date.day_number
# 從fromloc.city_name到toloc.city_name航班,flight,13.0,23.0,long beach,fromloc.city_name,27.0,36.0,nashville,toloc.city_name
# 節目航班class_type上airline_name從fromloc.city_name到toloc.airport_name,flight,13.0,24.0,first class,class_type,28.0,36.0,american,airline_name,42.0,59.0,dallas fort worth,fromloc.city_name,63.0,90.0,san francisco international,toloc.airport_name
# 我想要從fromloc.city_name一個depart_time.period_of_day depart_time.period_of_day flight_mod飛行toloc.city_name,flight,13.0,18.0,early,depart_time.period_of_day,19.0,26.0,morning,depart_time.period_of_day,27.0,34.0,weekday,flight_mod,47.0,56.0,san diego,fromloc.city_name,60.0,67.0,phoenix,toloc.city_name
# 有沒有從fromloc.city_name到toloc.city_name一個airline_code飛行,flight,11.0,14.0,twa,airline_code,27.0,36.0,las vegas,fromloc.city_name,40.0,48.0,new york,toloc.city_name
# 什麼flight_stop航班可從fromloc.city_name到toloc.city_name arrive_time.start_time和下午6點之間抵達,flight,5.0,12.0,nonstop,flight_stop,40.0,47.0,oakland,fromloc.city_name,51.0,63.0,philadelphia,toloc.city_name,81.0,82.0,5,arrive_time.start_time,87.0,91.0,06:00 PM,arrive_time.end_time
# 我需要從fromloc.city_name到toloc.city_name航班動態信息,flight,34.0,41.0,atlanta,fromloc.city_name,45.0,51.0,denver,toloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的flight_mod flight_time,flight_time,12.0,20.0,earliest,flight_mod,21.0,35.0,departure time,flight_time,41.0,47.0,boston,fromloc.city_name,51.0,57.0,denver,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name這toloc.city_name arrive_time.time_relative arrive_time.time arrive_date.today_relative到達所有航班,flight,25.0,38.0,san francisco,fromloc.city_name,42.0,52.0,pittsburgh,toloc.city_name,69.0,79.0,pittsburgh,toloc.city_name,80.0,86.0,before,arrive_time.time_relative,87.0,99.0,9 o'clock am,arrive_time.time,100.0,108.0,tomorrow,arrive_date.today_relative
# 有沒有從fromloc.city_name到toloc.city_name任何depart_time.time航班,flight,14.0,23.0,4 o'clock,depart_time.time,37.0,47.0,washington,fromloc.city_name,51.0,57.0,denver,toloc.city_name
# 什麼是fromloc.city_name到toloc.city_name的flight_mod飛行,flight,12.0,16.0,last,flight_mod,29.0,38.0,baltimore,fromloc.city_name,42.0,48.0,boston,toloc.city_name
# 從fromloc.city_name fromloc.state_name到toloc.city_name航班,flight,13.0,19.0,newark,fromloc.city_name,20.0,30.0,new jersey,fromloc.state_name,34.0,45.0,minneapolis,toloc.city_name
# 從fromloc.city_name到toloc.city_name depart_time.time_relative depart_time.time depart_date.day_name depart_time.period_of_day何去何從航班,flight,21.0,27.0,dallas,fromloc.city_name,31.0,44.0,san francisco,toloc.city_name,45.0,51.0,before,depart_time.time_relative,52.0,61.0,6 o'clock,depart_time.time,62.0,68.0,sunday,depart_date.day_name,69.0,78.0,afternoon,depart_time.period_of_day
# 我需要一個airline_name票class_type從fromloc.city_name到toloc.city_name定於depart_date.month_name depart_date.day_number,airfare,9.0,20.0,first class,class_type,31.0,46.0,united airlines,airline_name,52.0,58.0,denver,fromloc.city_name,62.0,71.0,baltimore,toloc.city_name,86.0,94.0,december,depart_date.month_name,95.0,106.0,seventeenth,depart_date.day_number
# 給我從fromloc.city_name的票價toloc.city_name航班上depart_date.month_name depart_date.day_number,flight,40.0,52.0,indianapolis,fromloc.city_name,56.0,63.0,orlando,toloc.city_name,67.0,75.0,december,depart_date.month_name,76.0,90.0,twenty seventh,depart_date.day_number
# 我要飛從fromloc.city_name到toloc.city_name,flight,19.0,25.0,boston,fromloc.city_name,29.0,38.0,baltimore,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name其離開depart_time.time_relative depart_time.time depart_date.today_relative所有航班,flight,25.0,35.0,pittsburgh,fromloc.city_name,39.0,46.0,atlanta,toloc.city_name,59.0,64.0,after,depart_time.time_relative,65.0,77.0,5 o'clock pm,depart_time.time,78.0,86.0,tomorrow,depart_date.today_relative
# 列出所有airline_name航班在其離開stoploc.city_name上fromloc.city_name和depart_date.day_name停止,flight,9.0,25.0,american airline,airline_name,46.0,53.0,phoenix,fromloc.city_name,57.0,66.0,wednesday,depart_date.day_name,79.0,88.0,milwaukee,stoploc.city_name
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name航班,flight,21.0,27.0,boston,fromloc.city_name,31.0,41.0,washington,toloc.city_name,45.0,51.0,monday,depart_date.day_name
# 我想要從fromloc.city_name的航班上depart_date.day_name toloc.city_name列表,flight,37.0,44.0,oakland,fromloc.city_name,48.0,65.0,dallas fort worth,toloc.city_name,69.0,75.0,sunday,depart_date.day_name
# 我找一個航班，depart_time.time離開fromloc.city_name,flight,25.0,31.0,boston,fromloc.city_name,35.0,45.0,12 o'clock,depart_time.time
# 有來自fromloc.city_name在depart_time.period_of_day飛行到達在arrive_time.period_of_day在toloc.city_name,flight,25.0,34.0,afternoon,depart_time.period_of_day,40.0,52.0,philadelphia,fromloc.city_name,73.0,80.0,evening,arrive_time.period_of_day,84.0,90.0,denver,toloc.city_name
# 什麼都在depart_date.day_name depart_time.period_of_day fromloc.city_name和toloc.city_name之間的票價,airfare,27.0,35.0,new york,fromloc.city_name,40.0,42.0,la,toloc.city_name,46.0,52.0,monday,depart_date.day_name,53.0,60.0,morning,depart_time.period_of_day
# 告訴我從fromloc.city_name到toloc.state_code上arrive_date.month_name arrive_date.day_number到達arrive_time.time_relative上午9點航班列表,flight,31.0,37.0,boston,fromloc.city_name,41.0,43.0,dc,toloc.state_code,53.0,59.0,before,arrive_time.time_relative,60.0,64.0,09:00 AM,arrive_time.time,68.0,72.0,july,arrive_date.month_name,73.0,86.0,twenty second,arrive_date.day_number
# 多少airline_name航班離開fromloc.city_name depart_date.month_name depart_date.day_number,quantity,9.0,25.0,american airline,airline_name,40.0,46.0,denver,fromloc.city_name,47.0,51.0,june,depart_date.month_name,52.0,57.0,tenth,depart_date.day_number
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,31.0,boston,fromloc.city_name,35.0,48.0,san francisco,toloc.city_name
# 我需要從fromloc.city_name到toloc.city_name toloc.state_name depart_date.date_relative depart_date.day_name飛,flight,19.0,26.0,atlanta,fromloc.city_name,30.0,39.0,charlotte,toloc.city_name,40.0,54.0,north carolina,toloc.state_name,55.0,59.0,next,depart_date.date_relative,60.0,66.0,monday,depart_date.day_name
# 我需要從fromloc.city_name到toloc.city_name depart_date.date_relative depart_date.day_name飛行到達在arrive_time.period_of_day toloc.city_name arrive_time.time_relative arrive_time.time,flight,21.0,32.0,kansas city,fromloc.city_name,36.0,43.0,chicago,toloc.city_name,44.0,48.0,next,depart_date.date_relative,49.0,58.0,wednesday,depart_date.day_name,72.0,79.0,chicago,toloc.city_name,80.0,86.0,around,arrive_time.time_relative,87.0,88.0,7,arrive_time.time,96.0,103.0,evening,arrive_time.period_of_day
# 告訴我從fromloc.city_name到toloc.city_name的cost_relative航班,flight,12.0,20.0,cheapest,cost_relative,34.0,47.0,san francisco,fromloc.city_name,51.0,63.0,philadelphia,toloc.city_name
# 從展示到fromloc.city_name所有toloc.city_name航班和票價,flight+airfare,32.0,42.0,pittsburgh,fromloc.city_name,46.0,59.0,san francisco,toloc.city_name
# 從fromloc.city_name到toloc.city_name顯示航班到達的arrive_time.time_relative arrive_time.time,flight,18.0,24.0,denver,fromloc.city_name,28.0,35.0,oakland,toloc.city_name,48.0,53.0,after,arrive_time.time_relative,54.0,64.0,12 o'clock,arrive_time.time
# 是什麼從fromloc.city_name到toloc.city_name航班,flight,26.0,32.0,boston,fromloc.city_name,36.0,49.0,san francisco,toloc.city_name
# 請告訴我從fromloc.city_name到toloc.city_name所有round_trip class_type航班,flight,19.0,26.0,one way,round_trip,27.0,38.0,first class,class_type,52.0,64.0,indianapolis,fromloc.city_name,68.0,75.0,memphis,toloc.city_name
# 請告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name航班,flight,28.0,34.0,dallas,fromloc.city_name,38.0,45.0,atlanta,toloc.city_name,49.0,55.0,monday,depart_date.day_name
# 我想要從fromloc.city_name到toloc.city_name上cost_relative機票round_trip信息,airfare,29.0,44.0,least expensive,cost_relative,53.0,63.0,round trip,round_trip,69.0,79.0,pittsburgh,fromloc.city_name,83.0,89.0,boston,toloc.city_name
# 確實airline_name飛從fromloc.city_name到toloc.city_name,flight,5.0,16.0,continental,airline_name,26.0,32.0,denver,fromloc.city_name,36.0,46.0,pittsburgh,toloc.city_name
# 我想要找到fromloc.city_name到toloc.city_name的cost_relative round_trip票價,airfare,22.0,37.0,least expensive,cost_relative,38.0,45.0,one way,round_trip,56.0,62.0,boston,fromloc.city_name,66.0,78.0,philadelphia,toloc.city_name
# 航空公司和航班號從fromloc.city_name到toloc.city_name,airline+flight_no,31.0,39.0,columbus,fromloc.city_name,43.0,54.0,minneapolis,toloc.city_name
# 從fromloc.city_name fromloc.state_code到toloc.city_name什麼航空公司,airline,19.0,29.0,washington,fromloc.city_name,30.0,32.0,dc,fromloc.state_code,36.0,44.0,columbus,toloc.city_name
# 告訴我就從airline_name到fromloc.city_name在toloc.city_name的depart_time.period_of_day depart_date.today_relative航班,flight,23.0,34.0,continental,airline_name,40.0,52.0,indianapolis,fromloc.city_name,56.0,65.0,san diego,toloc.city_name,73.0,82.0,afternoon,depart_time.period_of_day,83.0,91.0,tomorrow,depart_date.today_relative
# 從fromloc.city_name到toloc.city_name航班,flight,13.0,18.0,miami,fromloc.city_name,22.0,31.0,cleveland,toloc.city_name
# 從展示到fromloc.city_name航班toloc.city_name,flight,18.0,30.0,philadelphia,fromloc.city_name,34.0,40.0,boston,toloc.city_name
# 什麼airline_name航班可從fromloc.city_name到toloc.city_name,flight,5.0,10.0,delta,airline_name,38.0,48.0,pittsburgh,fromloc.city_name,52.0,65.0,san francisco,toloc.city_name
# ...
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,32.0,chicago,fromloc.city_name,36.0,48.0,indianapolis,toloc.city_name
# 所有航班toloc.city_name depart_time.time_relative 12點,flight,15.0,24.0,baltimore,toloc.city_name,25.0,30.0,after,depart_time.time_relative,31.0,36.0,12:00 PM,depart_time.time
# 你一定要toloc.city_name toloc.state_code flight_stop上depart_date.day_name一個航班從fromloc.city_name,flight,24.0,33.0,wednesday,depart_date.day_name,39.0,45.0,denver,fromloc.city_name,49.0,59.0,washington,toloc.city_name,60.0,62.0,dc,toloc.state_code,63.0,70.0,nonstop,flight_stop
# 我想要從fromloc.city_name飛到toloc.city_name,flight,22.0,28.0,boston,fromloc.city_name,32.0,42.0,fort worth,toloc.city_name
# 什麼航空公司的服務airport_name,airline,22.0,40.0,pittsburgh airport,airport_name
# 請從fromloc.city_name到toloc.city_name列出flight_time,flight_time,16.0,28.0,flight times,flight_time,34.0,44.0,pittsburgh,fromloc.city_name,48.0,54.0,newark,toloc.city_name
# 什麼是對depart_date.month_name票價depart_date.day_number從fromloc.city_name去round_trip到toloc.city_name,airfare,20.0,28.0,november,depart_date.month_name,29.0,36.0,seventh,depart_date.day_number,43.0,50.0,one way,round_trip,56.0,66.0,pittsburgh,fromloc.city_name,70.0,82.0,philadelphia,toloc.city_name
# 從fromloc.city_name飛往toloc.city_name上depart_date.month_name depart_date.day_number會是什麼cost_relative飛行,flight,12.0,22.0,pittsburgh,fromloc.city_name,26.0,33.0,atlanta,toloc.city_name,37.0,46.0,september,depart_date.month_name,47.0,53.0,fourth,depart_date.day_number,72.0,80.0,cheapest,cost_relative
# 什麼才是從fromloc.city_name到toloc.city_name票價,airfare,22.0,32.0,washington,fromloc.city_name,36.0,42.0,boston,toloc.city_name
# 確實airline_name飛從fromloc.city_name到toloc.city_name,flight,5.0,19.0,delta airlines,airline_name,29.0,39.0,pittsburgh,fromloc.city_name,43.0,50.0,atlanta,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,31.0,boston,fromloc.city_name,35.0,48.0,san francisco,toloc.city_name
# 你有沒有從fromloc.city_name一個airline_number航班到toloc.city_name,flight,14.0,20.0,united,airline_name,33.0,39.0,dallas,fromloc.city_name,43.0,56.0,san francisco,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name其離開fromloc.city_name depart_time.time_relative depart_time.time所有航班,flight,25.0,37.0,philadelphia,fromloc.city_name,41.0,47.0,denver,toloc.city_name,51.0,57.0,sunday,depart_date.day_name,70.0,82.0,philadelphia,fromloc.city_name,83.0,88.0,after,depart_time.time_relative,89.0,93.0,noon,depart_time.time
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name航班,flight,21.0,27.0,dallas,fromloc.city_name,31.0,44.0,san francisco,toloc.city_name,48.0,58.0,wednesdays,depart_date.day_name
# 在airline_code到toloc.city_name航班從fromloc.city_name,flight,11.0,14.0,twa,airline_code,20.0,28.0,columbus,fromloc.city_name,32.0,41.0,st. louis,toloc.city_name
# 是什麼從fromloc.city_name到toloc.city_name航班為depart_date.day_name的depart_date.day_number,flight,26.0,35.0,cleveland,fromloc.city_name,39.0,51.0,indianapolis,toloc.city_name,56.0,65.0,wednesday,depart_date.day_name,70.0,77.0,twelfth,depart_date.day_number
# 我想從fromloc.city_name前往toloc.city_name上depart_date.day_name depart_time.period_of_day,flight,22.0,34.0,philadelphia,fromloc.city_name,38.0,44.0,boston,toloc.city_name,48.0,57.0,wednesday,depart_date.day_name,58.0,67.0,afternoon,depart_time.period_of_day
# 我想要從fromloc.city_name去toloc.city_name上depart_date.day_name depart_time.period_of_day depart_date.month_name depart_date.day_number,flight,21.0,28.0,detroit,fromloc.city_name,32.0,41.0,san diego,toloc.city_name,45.0,54.0,wednesday,depart_date.day_name,55.0,62.0,evening,depart_time.period_of_day,63.0,67.0,june,depart_date.month_name,68.0,74.0,second,depart_date.day_number
# 告訴我從fromloc.city_name到toloc.city_name上depart_date.day_name航班,flight,21.0,27.0,denver,fromloc.city_name,31.0,37.0,boston,toloc.city_name,41.0,49.0,thursday,depart_date.day_name
# 我想從fromloc.city_name到toloc.city_name的flight_days航班列表,flight,19.0,24.0,daily,flight_days,38.0,47.0,milwaukee,fromloc.city_name,51.0,60.0,st. louis,toloc.city_name
# 多少做了class_type機票費用從fromloc.city_name到toloc.city_name round_trip,airfare,16.0,27.0,first class,class_type,45.0,51.0,boston,fromloc.city_name,55.0,68.0,san francisco,toloc.city_name,69.0,79.0,round trip,round_trip
# 請告訴我航班airline_code次航班從fromloc.city_name到toloc.city_name和飛行airline_code次航班的成本從fromloc.city_name到toloc.city_name,airfare,34.0,36.0,ua,airline_code,37.0,40.0,201,flight_number,46.0,52.0,boston,fromloc.city_name,56.0,62.0,denver,toloc.city_name,74.0,76.0,ua,airline_code,77.0,80.0,343,flight_number,86.0,92.0,boston,fromloc.city_name,96.0,102.0,denver,toloc.city_name
# 顯示航班離開fromloc.city_name到toloc.city_name上airline_name即離開depart_time.time_relative depart_time.time,flight,21.0,26.0,miami,fromloc.city_name,30.0,39.0,cleveland,toloc.city_name,43.0,49.0,us air,airline_name,61.0,66.0,after,depart_time.time_relative,67.0,71.0,noon,depart_time.time
# 請告訴我從fromloc.city_name到toloc.city_name toloc.state_name上depart_date.day_name depart_time.time_relative depart_time.time航班,flight,28.0,35.0,atlanta,fromloc.city_name,39.0,46.0,oakland,toloc.city_name,47.0,57.0,california,toloc.state_name,61.0,69.0,thursday,depart_date.day_name,70.0,75.0,after,depart_time.time_relative,76.0,86.0,1600 hours,depart_time.time
# 從fromloc.city_name fromloc.state_code到toloc.city_name depart_time.time_relative下午5時的所有航班上depart_date.month_name depart_date.day_number經濟,flight,17.0,27.0,washington,fromloc.city_name,28.0,30.0,dc,fromloc.state_code,34.0,47.0,san francisco,toloc.city_name,48.0,53.0,after,depart_time.time_relative,54.0,58.0,05:00 PM,depart_time.time,62.0,70.0,november,depart_date.month_name,71.0,78.0,twelfth,depart_date.day_number,79.0,92.0,economy class,economy
# 在airline_name flight_mod航班從fromloc.city_name fromloc.state_code到toloc.city_name,flight,1.0,9.0,earliest,flight_mod,19.0,36.0,american airlines,airline_name,42.0,52.0,washington,fromloc.city_name,53.0,55.0,dc,fromloc.state_code,59.0,72.0,san francisco,toloc.city_name
# 什麼航班你有從fromloc.city_name對depart_date.date_relative週depart_date.day_name toloc.city_name depart_time.time_relative下午6點,flight,30.0,36.0,boston,fromloc.city_name,40.0,50.0,pittsburgh,toloc.city_name,54.0,63.0,wednesday,depart_date.day_name,67.0,71.0,next,depart_date.date_relative,77.0,82.0,after,depart_time.time_relative,83.0,87.0,06:00 PM,depart_time.time
# 從列出來fromloc.city_name的toloc.city_name航班depart_date.day_name和arrive_time.start_time之間arrive_time.end_time在toloc.city_name抵達,flight,9.0,18.0,wednesday,depart_date.day_name,32.0,38.0,denver,fromloc.city_name,42.0,51.0,baltimore,toloc.city_name,64.0,73.0,baltimore,toloc.city_name,82.0,89.0,1115 am,arrive_time.start_time,94.0,101.0,1245 pm,arrive_time.end_time
# 什麼是fromloc.city_name的flight_mod飛行toloc.city_name離開depart_date.month_name depart_date.day_number,flight,12.0,20.0,earliest,flight_mod,33.0,39.0,boston,fromloc.city_name,43.0,60.0,dallas fort worth,toloc.city_name,69.0,75.0,august,depart_date.month_name,76.0,82.0,eighth,depart_date.day_number
# 什麼是從fromloc.city_name到toloc.city_name S中class_type票價round_trip,airfare,12.0,23.0,first class,class_type,29.0,39.0,round trip,round_trip,45.0,52.0,atlanta,fromloc.city_name,56.0,62.0,denver,toloc.city_name
# 什麼是class_type票價從fromloc.city_name對depart_date.day_name toloc.city_name,airfare,13.0,24.0,first class,class_type,36.0,42.0,boston,fromloc.city_name,46.0,56.0,pittsburgh,toloc.city_name,60.0,68.0,thursday,depart_date.day_name
# 從fromloc.city_name到toloc.city_name航班,flight,13.0,21.0,montreal,fromloc.city_name,25.0,34.0,las vegas,toloc.city_name
# 我需要去從fromloc.city_name到toloc.city_name,flight,18.0,24.0,boston,fromloc.city_name,28.0,34.0,dallas,toloc.city_name
# 是什麼fromloc.city_name到toloc.city_name的depart_time.period_of_day航班,flight,13.0,22.0,afternoon,depart_time.period_of_day,35.0,41.0,denver,fromloc.city_name,45.0,58.0,san francisco,toloc.city_name
# 從列出來fromloc.city_name的toloc.city_name航班,flight,22.0,28.0,denver,fromloc.city_name,32.0,41.0,baltimore,toloc.city_name
# 什麼flight_stop航班可從fromloc.city_name到toloc.city_name,flight,5.0,12.0,nonstop,flight_stop,40.0,47.0,oakland,fromloc.city_name,51.0,61.0,pittsburgh,toloc.city_name
# 什麼是我的fromloc.city_name回toloc.city_name飛行depart_time.time_relative depart_time.time選項,flight,26.0,37.0,minneapolis,fromloc.city_name,46.0,58.0,indianapolis,toloc.city_name,66.0,72.0,around,depart_time.time_relative,73.0,81.0,noontime,depart_time.time
# 告訴我從fromloc.city_name到toloc.city_name航班,flight,25.0,34.0,san diego,fromloc.city_name,38.0,44.0,newark,toloc.city_name
# 好吧，我想飛行原產於fromloc.city_name要toloc.city_name,flight,36.0,42.0,denver,fromloc.city_name,52.0,62.0,pittsburgh,toloc.city_name
# 是什麼的所有航班從fromloc.city_name對depart_date.day_name toloc.city_name,flight,26.0,38.0,philadelphia,fromloc.city_name,42.0,48.0,denver,toloc.city_name,52.0,62.0,wednesdays,depart_date.day_name
# 什麼航班都可以從depart_date.day_name到fromloc.city_name toloc.city_name,flight,27.0,33.0,friday,depart_date.day_name,39.0,52.0,san francisco,fromloc.city_name,56.0,62.0,boston,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name其離開depart_time.time_relative depart_time.time所有航班,flight,25.0,35.0,pittsburgh,fromloc.city_name,39.0,45.0,boston,toloc.city_name,58.0,64.0,before,depart_time.time_relative,65.0,69.0,noon,depart_time.time
# 我需要十個人從fromloc.city_name到toloc.city_name請給我的航班flight_mod,flight,31.0,37.0,denver,fromloc.city_name,41.0,48.0,phoenix,toloc.city_name,76.0,91.0,during the week,flight_mod
# 我想從fromloc.city_name前往toloc.city_name depart_time.period_mod在depart_time.period_of_day,flight,28.0,34.0,boston,fromloc.city_name,38.0,44.0,denver,toloc.city_name,45.0,50.0,early,depart_time.period_mod,58.0,65.0,morning,depart_time.period_of_day
# 什麼航班從fromloc.city_name到toloc.city_name,flight,18.0,32.0,salt lake city,fromloc.city_name,36.0,45.0,las vegas,toloc.city_name
# 什麼航班都可以depart_date.day_name depart_time.period_of_day從fromloc.city_name到toloc.city_name,flight,27.0,34.0,tuesday,depart_date.day_name,35.0,44.0,afternoon,depart_time.period_of_day,50.0,60.0,pittsburgh,fromloc.city_name,64.0,71.0,atlanta,toloc.city_name
# flight_stop或連接航班從fromloc.city_name到toloc.city_name,flight,1.0,8.0,nonstop,flight_stop,8.0,10.0,or,or,11.0,21.0,connecting,connect,35.0,42.0,seattle,fromloc.city_name,46.0,52.0,boston,toloc.city_name
# 什麼航班從fromloc.city_name到toloc.city_name,flight,18.0,28.0,cincinnati,fromloc.city_name,32.0,37.0,tampa,toloc.city_name
# 從fromloc.city_name fromloc.state_name到toloc.city_name toloc.state_name所有航班,flight,17.0,23.0,denver,fromloc.city_name,24.0,32.0,colorado,fromloc.state_name,36.0,46.0,pittsburgh,toloc.city_name,47.0,59.0,pennsylvania,toloc.state_name
# 有沒有從fromloc.city_name飛行到toloc.city_name在depart_time.period_of_day depart_date.today_relative,flight,23.0,32.0,nashville,fromloc.city_name,36.0,43.0,houston,toloc.city_name,51.0,58.0,evening,depart_time.period_of_day,59.0,67.0,tomorrow,depart_date.today_relative
# 什麼是你已經離開fromloc.city_name到toloc.city_name的flight_mod飛行,flight,12.0,18.0,latest,flight_mod,45.0,51.0,dallas,fromloc.city_name,55.0,67.0,philadelphia,toloc.city_name
# 告訴我從fromloc.city_name到toloc.city_name航班depart_date.day_name depart_time.time_relative下午6時，,flight,21.0,30.0,milwaukee,fromloc.city_name,34.0,41.0,orlando,toloc.city_name,45.0,54.0,wednesday,depart_date.day_name,55.0,60.0,after,depart_time.time_relative,61.0,65.0,06:00 PM,depart_time.time
# 給我從fromloc.city_name的cost_relative票價上depart_date.month_name depart_date.day_number toloc.city_name請,airfare,12.0,18.0,lowest,cost_relative,29.0,36.0,atlanta,fromloc.city_name,40.0,46.0,denver,toloc.city_name,50.0,53.0,may,depart_date.month_name,54.0,61.0,seventh,depart_date.day_number
# 告訴我從fromloc.city_name到toloc.city_name的cost_relative航班,flight,12.0,20.0,cheapest,cost_relative,34.0,43.0,baltimore,fromloc.city_name,47.0,53.0,dallas,toloc.city_name
# 當在flight_mod航班從fromloc.city_name留給toloc.city_name,flight,12.0,17.0,first,flight_mod,38.0,45.0,oakland,fromloc.city_name,49.0,55.0,boston,toloc.city_name
# 找到fromloc.city_name到toloc.city_name停止在stoploc.city_name所有航班,flight,22.0,34.0,philadelphia,fromloc.city_name,38.0,44.0,dallas,toloc.city_name,57.0,64.0,atlanta,stoploc.city_name
# 清單airline_name航班從fromloc.city_name到toloc.city_name,flight,5.0,22.0,american airlines,airline_name,36.0,42.0,newark,fromloc.city_name,46.0,55.0,nashville,toloc.city_name
# 可我看到fromloc.city_name到toloc.city_name所有的航班，請,flight,31.0,41.0,washington,fromloc.city_name,45.0,58.0,san francisco,toloc.city_name
# 告訴我航班，從fromloc.airport_name,flight,32.0,42.0,love field,fromloc.airport_name
# 我想從fromloc.city_name到toloc.city_name飛行airline_name上的一些信息,flight,47.0,53.0,denver,fromloc.city_name,57.0,70.0,san francisco,toloc.city_name,74.0,89.0,united airlines,airline_name
# 我想從fromloc.city_name到toloc.city_name飛行，在stoploc.city_name停止,flight,21.0,31.0,long beach,fromloc.city_name,35.0,44.0,st. louis,toloc.city_name,59.0,65.0,dallas,stoploc.city_name
# 我想要看到來自fromloc.city_name到toloc.city_name的round_trip航班,flight,25.0,32.0,one way,round_trip,46.0,52.0,denver,fromloc.city_name,56.0,66.0,pittsburgh,toloc.city_name
# 我想要fromloc.city_name到toloc.city_name到達arrive_time.time_relative arrive_time.time上的airline_name航班,flight,21.0,38.0,american airlines,airline_name,44.0,56.0,philadelphia,fromloc.city_name,60.0,66.0,dallas,toloc.city_name,76.0,82.0,before,arrive_time.time_relative,83.0,90.0,1145 am,arrive_time.time
# 是什麼從fromloc.city_name到toloc.city_name的depart_time.period_of_day航班,flight,13.0,20.0,morning,depart_time.period_of_day,34.0,40.0,boston,fromloc.city_name,44.0,56.0,philadelphia,toloc.city_name
# 一個class_type飛行toloc.city_name上airline_name depart_date.day_name depart_date.date_relative週,flight,2.0,13.0,first class,class_type,24.0,37.0,san francisco,toloc.city_name,41.0,58.0,american airlines,airline_name,59.0,66.0,tuesday,depart_date.day_name,67.0,71.0,next,depart_date.date_relative
# 我需要對depart_date.day_name離開fromloc.city_name到toloc.city_name和fromloc.city_name到toloc.city_name的航班，toloc.city_name fromloc.city_name信息,flight,34.0,41.0,tuesday,depart_date.day_name,50.0,59.0,baltimore,fromloc.city_name,64.0,70.0,dallas,toloc.city_name,71.0,77.0,dallas,fromloc.city_name,81.0,87.0,boston,toloc.city_name,92.0,98.0,boston,fromloc.city_name,102.0,111.0,baltimore,toloc.city_name
# 現在向我展示從fromloc.city_name到toloc.city_name航班,flight,25.0,35.0,pittsburgh,fromloc.city_name,39.0,51.0,philadelphia,toloc.city_name
# 有沒有從fromloc.city_name到toloc.city_name任何連接航班在toloc.city_name arrive_time.time_relative arrive_time.time到達,flight,14.0,20.0,direct,connect,34.0,41.0,atlanta,fromloc.city_name,45.0,57.0,philadelphia,toloc.city_name,70.0,82.0,philadelphia,toloc.city_name,83.0,88.0,about,arrive_time.time_relative,89.0,96.0,12 noon,arrive_time.time
# 什麼是fromloc.city_name的flight_mod航班上depart_date.day_name toloc.city_name toloc.state_code,flight,12.0,20.0,earliest,flight_mod,33.0,40.0,oakland,fromloc.city_name,44.0,54.0,washington,toloc.city_name,55.0,57.0,dc,toloc.state_code,61.0,67.0,sunday,depart_date.day_name
# 什麼航空公司從fromloc.city_name到toloc.city_name飛,airline,23.0,29.0,boston,fromloc.city_name,33.0,43.0,pittsburgh,toloc.city_name
# 我想從一個fromloc.city_name飛行toloc.city_name在stoploc.city_name停在那裡航班,flight,21.0,28.0,toronto,fromloc.city_name,32.0,41.0,san diego,toloc.city_name,56.0,65.0,st. louis,stoploc.city_name
# 你能告訴我從fromloc.city_name到toloc.city_name的cost_relative飛行,flight,29.0,37.0,cheapest,cost_relative,50.0,56.0,boston,fromloc.city_name,60.0,73.0,san francisco,toloc.city_name
# 從fromloc.city_name到toloc.city_name,flight,5.0,14.0,las vegas,fromloc.city_name,18.0,26.0,montreal,toloc.city_name
# 什麼airline_name航班離開fromloc.city_name depart_time.time_relative depart_time.time,flight,5.0,22.0,northwest airline,airline_name,37.0,43.0,denver,fromloc.city_name,44.0,50.0,before,depart_time.time_relative,51.0,55.0,noon,depart_time.time
# 顯示在airline_name從fromloc.city_name到toloc.city_name到toloc.city_name toloc.state_code所有航班,flight,20.0,35.0,united airlines,airline_name,41.0,54.0,san francisco,fromloc.city_name,58.0,64.0,denver,toloc.city_name,68.0,78.0,washington,toloc.city_name,79.0,81.0,dc,toloc.state_code
